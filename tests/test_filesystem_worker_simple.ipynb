# %%
from time import sleep

from distributed_processing.utils import fsworker

# %%
CURRO = True

if CURRO:
    NS_PATH ="G:\\fs_namespaces\\prueba_distribuida"
    NS_PATH ="C:\\fs_namespaces\\prueba_distribuida"

else:
    NS_PATH = "/home/augusto/python/notebooks/fs_namespaces/prueba_distribuida"

# %%
import logging

logging.getLogger("distributed_processing").setLevel(logging.DEBUG)

# %%
# clean = True limpia namespace. Por defecto, False 
server = fsworker(NS_PATH, clean=True)
# Out:
# 2026-02-24T16:07:49.724738 nservers_lock set in C:\fs_namespaces\prueba_distribuida\ud_variables
# 2026-02-24T16:07:49.748089 nservers_lock unset in C:\fs_namespaces\prueba_distribuida\ud_variables
# Worker id: fs_server_1

# %%
def info():
    return server.worker_id, server.requests_queues

server.add_requests_queue(server.worker_id, {"info":info})

# %%
def add(x, y):
    return x + y

def mul(x, y):
    return x * y

def div(x, y):
    return x / y

def lista(x, y):
    return [x, y]

def tupla(x, y):
    return (x,y)

def dic(x,y):
    return {"a":x, "b":[x,y]}

func_dict1 = {"add" : add,
              "mul" : mul,
              "div" : div,
              "lista" : lista,
              "tupla" : tupla,
              "dic" :dic,
              "sleep": sleep}

server.add_requests_queue("cola_1", func_dict1)

# %%
def hola(nombre, calificativo="listo"):
    return f"Hola {nombre}, eres muy {calificativo}"

func_dict2 = {"hola": hola}

# Los métodos disponibles en cola_2 no los vamos a hacer públicos
server.add_requests_queue("cola_2", func_dict2, register=False)

# %%
server.add_python_eval()

"""
# Equivalente a:
import dill
import base64

def eval_py_function(str_fn, args=[], kwargs={}):
    "str_fn encoded en base64 ascii"
    return dill.loads(base64.b64decode(str_fn))(*args, **kwargs)

server.add_requests_queue("py_eval", {"eval_py_function": eval_py_function})
"""
# Out:
# '\n# Equivalente a:\nimport dill\nimport base64\n\ndef eval_py_function(str_fn, args=[], kwargs={}):\n    "str_fn encoded en base64 ascii"\n    return dill.loads(base64.b64decode(str_fn))(*args, **kwargs)\n\nserver.add_requests_queue("py_eval", {"eval_py_function": eval_py_function})\n'

# %%
server.queues_to_register
# Out:
# {'requests_cola_1', 'requests_fs_server_1', 'requests_py_eval'}

# %%
# Publicamos todos los métodos de las colas 
server.update_methods_registry()
# Out:
# 2026-02-24T16:07:49.912903 registry_lock set in C:\fs_namespaces\prueba_distribuida\ud_variables
# Method info published as available for queues: requests_fs_server_1
# Method add published as available for queues: requests_cola_1
# Method mul published as available for queues: requests_cola_1
# Method div published as available for queues: requests_cola_1
# Method lista published as available for queues: requests_cola_1
# Method tupla published as available for queues: requests_cola_1
# Method dic published as available for queues: requests_cola_1
# Method sleep published as available for queues: requests_cola_1
# Method eval_py_function published as available for queues: requests_py_eval
# 2026-02-24T16:07:50.082479 registry_lock unset in C:\fs_namespaces\prueba_distribuida\ud_variables
# {'requests_fs_server_1': {'info': <function info at 0x00000202DC39CFE0>}, 'requests_cola_1': {'add': <function add at 0x00000202F4B40220>, 'mul': <function mul at 0x00000202F4B402C0>, 'div': <function div at 0x00000202F4B40360>, 'lista': <function lista at 0x00000202F4B40400>, 'tupla': <function tupla at 0x00000202F4B404A0>, 'dic': <function dic at 0x00000202F4B40540>, 'sleep': <built-in function sleep>}, 'requests_py_eval': {'eval_py_function': <function eval_py_function at 0x00000202DC590B80>}}

# %%
server.run()
# Out:
# 2026-02-24T16:07:50.109531 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:07:50.114081 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:07:50.115857 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:07:50.120685 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:07:50.122504 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:07:50.125976 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:07:50.128721 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:07:50.132705 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.137615 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.140589 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.142070 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.145582 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.147140 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.150230 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.151900 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.166198 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.167144 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:08:21.188853 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:1 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:08:21.210602 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.217337 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.222024 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.233426 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.235904 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.239968 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.242241 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.248020 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.353863 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.356634 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.358322 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.371581 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.372340 Worker: fs_server_1 Received Single Request for method: fake from queue: requests_cola_1
# 2026-02-24T16:08:21.391836 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:2 for method: fake to queue: fs_client_1_responses
# 2026-02-24T16:08:21.401073 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.404046 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.405465 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.408460 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.410468 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.414422 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.415860 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.419125 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.549052 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.553608 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.555795 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.566876 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.568870 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.589984 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.591624 Worker: fs_server_1 Received Single Request for method: fake from queue: requests_cola_1
# 2026-02-24T16:08:21.616291 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:3 for method: fake to queue: fs_client_1_responses
# 2026-02-24T16:08:21.627890 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.633301 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.635563 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.638767 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.639922 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.643225 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.645001 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.647896 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.751859 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.754817 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.756296 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.759430 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.761115 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.772032 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.772883 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-02-24T16:08:21.795008 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:4 for method: div to queue: fs_client_1_responses
# 2026-02-24T16:08:21.802111 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.805787 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:21.807195 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.810678 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:21.812338 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.816565 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:21.818289 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:21.820944 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.001664 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.004288 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.005603 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.008498 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.010564 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.023491 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.024381 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:08:22.047818 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:5 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:08:22.057519 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.061471 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.063203 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.066260 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.067744 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.070488 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.071846 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.077254 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.252673 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.265486 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.266462 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_py_eval
# 2026-02-24T16:08:22.300249 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:6 for method: eval_py_function to queue: fs_client_1_responses
# 2026-02-24T16:08:22.312412 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.316621 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.318690 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.322886 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.325007 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.330057 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.332059 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.335937 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.440971 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.454040 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.454973 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_py_eval
# 2026-02-24T16:08:22.477765 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:7 for method: eval_py_function to queue: fs_client_1_responses
# 2026-02-24T16:08:22.486156 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.489256 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.490598 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.493980 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.495578 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.498709 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.500341 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.502978 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.639572 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.646544 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.648963 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.652793 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.654220 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.657422 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.659150 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.671670 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.672246 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:08:22.703690 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:8 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:08:22.718080 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.721943 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.723324 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.726899 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.729247 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.732256 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.733566 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.746723 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.747748 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:08:22.765335 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:9 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:08:22.772843 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.776244 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.778138 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.780620 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.781673 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.793793 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.794960 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-02-24T16:08:22.812724 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:10 for method: div to queue: fs_client_1_responses
# 2026-02-24T16:08:22.820915 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.823750 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.825348 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.828548 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.830129 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.844157 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.845052 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:22.863465 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:11 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:22.871345 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.874703 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.876661 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.880021 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:22.882134 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.886228 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:22.887862 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.903901 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.905024 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:22.927752 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:12 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:22.939495 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.947521 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:22.949672 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.979104 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:22.980496 Worker: fs_server_1 Received Single Request for method: dic from queue: requests_cola_1
# 2026-02-24T16:08:23.015096 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:13 for method: dic to queue: fs_client_1_responses
# 2026-02-24T16:08:23.021815 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.024566 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.029653 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.048312 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.049144 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:23.070482 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:14 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:23.081484 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.084623 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.086163 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:23.090215 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:23.092195 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.107718 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.108903 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:23.131835 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:15 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:23.139477 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.143518 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.145784 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:23.149221 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:23.150885 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:23.154929 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:23.156479 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.173105 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.173989 Worker: fs_server_1 Received Single Request for method: tupla from queue: requests_cola_1
# 2026-02-24T16:08:23.206108 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:16 for method: tupla to queue: fs_client_1_responses
# 2026-02-24T16:08:23.214873 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.217378 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.218428 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:23.220730 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:23.222065 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:23.224416 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:23.226076 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.237740 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.238481 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-02-24T16:08:23.259002 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:17 for method: div to queue: fs_client_1_responses
# 2026-02-24T16:08:23.267721 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.270898 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:23.272514 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:23.275348 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:23.277206 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.289769 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:23.290619 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-02-24T16:08:33.310007 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:18 for method: sleep to queue: fs_client_1_responses
# 2026-02-24T16:08:33.316851 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.319393 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.321010 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:33.323926 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:33.325261 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:33.328234 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:33.329419 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.331955 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.412146 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.415267 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.416691 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:33.419288 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:33.421226 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:33.424504 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:33.426172 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.441177 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.442463 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:08:33.461957 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:19 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:08:33.472534 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.479213 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.480605 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:33.483499 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:33.484983 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.498618 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.499650 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:08:33.531444 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:20 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:08:33.546545 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.550255 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.557086 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.579684 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.580760 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-02-24T16:08:33.601220 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:21 for method: div to queue: fs_client_1_responses
# 2026-02-24T16:08:33.609483 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.614502 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.616943 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.634143 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.635143 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:33.657334 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:22 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:33.666939 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.670738 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.672805 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.699729 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.700755 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:33.729521 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:23 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:33.738069 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.741687 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.743165 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:33.745893 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:33.747714 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.761359 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.762419 Worker: fs_server_1 Received Single Request for method: dic from queue: requests_cola_1
# 2026-02-24T16:08:33.782951 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:24 for method: dic to queue: fs_client_1_responses
# 2026-02-24T16:08:33.791158 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.793687 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.794964 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.807119 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.808405 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:33.829249 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:25 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:33.837568 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.841604 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.842956 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.855124 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.856307 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-02-24T16:08:33.877739 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:26 for method: lista to queue: fs_client_1_responses
# 2026-02-24T16:08:33.885121 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.888825 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.890090 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.901285 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.902232 Worker: fs_server_1 Received Single Request for method: tupla from queue: requests_cola_1
# 2026-02-24T16:08:33.926149 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:27 for method: tupla to queue: fs_client_1_responses
# 2026-02-24T16:08:33.932986 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.935678 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.937363 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.947883 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:33.948530 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-02-24T16:08:33.969234 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:28 for method: div to queue: fs_client_1_responses
# 2026-02-24T16:08:33.983495 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.991370 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:33.994777 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:34.001112 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:34.004351 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:34.009340 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:34.011512 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:34.048387 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:34.049627 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-02-24T16:08:44.070682 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:29 for method: sleep to queue: fs_client_1_responses
# 2026-02-24T16:08:44.077537 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:44.080046 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:44.081084 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:44.084335 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:44.085912 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:44.088897 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:44.090045 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:44.092340 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:44.338143 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:44.341196 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:44.343438 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:44.359826 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:44.360751 Worker: fs_server_1 Received Batch Request with 11 requests from queue: requests_cola_1
# 2026-02-24T16:08:54.362016 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:30 for method: add from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.362839 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:31 for method: add from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.363307 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:32 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.363985 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:33 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.364569 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:34 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.365202 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:35 for method: dic from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.365874 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:36 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.366398 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:37 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.366978 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:38 for method: tupla from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.367600 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:39 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.368204 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:40 for method: sleep from Batch Request from queue: requests_cola_1
# 2026-02-24T16:08:54.388544 Worker: fs_server_1 Sent Batch Response with 11 items to queue fs_client_1_responses
# 2026-02-24T16:08:54.396330 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:54.399129 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:54.400441 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:54.403380 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:54.404575 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:54.407425 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:54.408549 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:54.411442 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:54.593944 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:54.597169 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:08:54.598419 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:54.600718 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:08:54.601799 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:54.604263 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:08:54.605565 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:54.618057 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:08:54.618914 Worker: fs_server_1 Received Batch Request with 11 requests from queue: requests_cola_1
# 2026-02-24T16:09:04.620376 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:41 for method: add from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.621110 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:42 for method: add from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.621673 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:43 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.622256 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:44 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.623016 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:45 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.623861 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:46 for method: dic from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.624312 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:47 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.624737 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:48 for method: lista from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.625117 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:49 for method: tupla from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.625556 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:50 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.626010 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:51 for method: sleep from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.644409 Worker: fs_server_1 Sent Batch Response with 11 items to queue fs_client_1_responses
# 2026-02-24T16:09:04.651238 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:04.653920 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:04.654935 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:04.658353 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:04.659659 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:04.662315 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:04.663348 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:04.665712 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:04.850519 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:04.862813 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:04.866889 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:04.871311 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:04.874728 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:04.896174 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:04.897722 Worker: fs_server_1 Received Batch Request with 10 requests from queue: requests_cola_1
# 2026-02-24T16:09:04.898923 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:52 for method: mul from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.900095 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:53 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.900740 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:54 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.901429 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:55 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.902062 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:56 for method: mul from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.902751 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:57 for method: mul from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.903368 Worker: fs_server_1 Appending ERROR response with id: fs_client_1:58 for method: fake from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.903996 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:59 for method: div from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.904926 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:60 for method: mul from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.907513 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:61 for method: add from Batch Request from queue: requests_cola_1
# 2026-02-24T16:09:04.932903 Worker: fs_server_1 Sent Batch Response with 10 items to queue fs_client_1_responses
# 2026-02-24T16:09:04.943084 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:04.948613 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:04.951383 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:04.957843 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:04.959981 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:04.963281 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:04.964681 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:04.967360 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.170188 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.175676 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.178538 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:05.183462 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:05.186238 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.190963 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.195684 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.233011 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.235257 Worker: fs_server_1 Received Single Request for method: kk from queue: requests_cola_1
# 2026-02-24T16:09:05.255027 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:62 for method: kk to queue: fs_client_1_responses
# 2026-02-24T16:09:05.274612 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.278465 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.280069 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.283563 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.285402 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.289342 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.291116 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:05.294994 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:05.426016 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.429123 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.430813 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.446177 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.447057 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-02-24T16:09:05.484444 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:63 for method: add to queue: fs_client_1_responses
# 2026-02-24T16:09:05.501792 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.507407 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.511239 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.515717 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.517633 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.521865 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.524031 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:05.529790 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T16:09:05.605328 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.608175 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.609503 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.624912 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T16:09:05.625977 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_cola_1
# 2026-02-24T16:09:05.648469 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:64 for method: eval_py_function to queue: fs_client_1_responses
# 2026-02-24T16:09:05.677060 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.681455 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T16:09:05.683534 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T16:09:05.691603 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# ...
# 2026-02-24T17:10:04.205453 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:10:04.206669 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:10:04.208675 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:10:04.209786 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:10:04.211837 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:10:04.212854 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:10:04.214734 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:11:04.247644 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:11:04.249851 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:11:04.251007 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:11:04.252922 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:11:04.253884 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:11:04.255816 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:11:04.256910 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:11:04.258902 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:12:04.358938 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:12:04.361330 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:12:04.362767 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:12:04.364914 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:12:04.366125 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:12:04.368484 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:12:04.369547 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:12:04.371506 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:13:04.431510 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:13:04.433682 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:13:04.434665 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:13:04.436740 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:13:04.437756 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:13:04.439915 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:13:04.441420 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:13:04.443422 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:14:04.518959 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:14:04.521482 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:14:04.522622 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:14:04.524728 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:14:04.525872 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:14:04.527823 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:14:04.529355 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:14:04.531604 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:15:04.633124 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:15:04.635194 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:15:04.636394 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:15:04.638087 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:15:04.639107 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:15:04.641041 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:15:04.642055 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:15:04.643930 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:16:04.664279 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:16:04.666558 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:16:04.667716 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:16:04.669580 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:16:04.670650 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:16:04.672909 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:16:04.674219 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:16:04.676323 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:17:04.707335 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:17:04.709481 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:17:04.710691 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:17:04.712798 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:17:04.713824 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:17:04.715794 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:17:04.717136 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:17:04.719136 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:18:04.794077 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:18:04.796361 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:18:04.797540 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:18:04.799484 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:18:04.800456 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:18:04.802346 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:18:04.803442 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:18:04.805326 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:19:04.883451 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:19:04.885712 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:19:04.886976 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:19:04.889102 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:19:04.890059 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:19:04.891893 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:19:04.893177 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:19:04.895257 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:20:04.927714 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:20:04.929722 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:20:04.931113 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:20:04.932893 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:20:04.934065 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:20:04.935986 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:20:04.937151 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:20:04.939025 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:21:04.975614 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:21:04.977778 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:21:04.979279 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:21:04.981228 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:21:04.982447 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:21:04.984333 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:21:04.985304 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:21:04.987214 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:22:05.092657 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:22:05.094971 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:22:05.096108 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:22:05.097950 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:22:05.099138 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:22:05.101015 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:22:05.101970 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:22:05.103843 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:23:05.140452 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:23:05.142855 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:23:05.143832 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:23:05.145778 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:23:05.146856 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:23:05.148720 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:23:05.149668 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:23:05.151629 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:24:05.221109 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:24:05.223288 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:24:05.224392 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:24:05.226586 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:24:05.227659 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:24:05.229682 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:24:05.230909 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:24:05.232791 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:25:05.327065 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:25:05.329217 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:25:05.330263 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:25:05.332525 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:25:05.333606 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:25:05.335462 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:25:05.336698 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:25:05.338571 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:26:05.387193 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:26:05.389621 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:26:05.390974 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:26:05.393156 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:26:05.394141 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:26:05.396035 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:26:05.397170 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:26:05.398973 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:27:05.443439 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:27:05.445623 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:27:05.446851 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:27:05.449148 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:27:05.450299 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:27:05.452555 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:27:05.453612 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:27:05.456415 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:28:05.534929 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:28:05.537238 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_py_eval
# 2026-02-24T17:28:05.538415 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:28:05.540316 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_fs_server_1
# 2026-02-24T17:28:05.541693 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:28:05.543803 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_1
# 2026-02-24T17:28:05.544866 pop_left_lock set in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
# 2026-02-24T17:28:05.546803 pop_left_lock unset in C:\fs_namespaces\prueba_distribuida\li_requests_cola_2
