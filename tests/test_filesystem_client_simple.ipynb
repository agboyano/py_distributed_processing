# %%
import random

from distributed_processing.utils import fsclient

# %%
CURRO = True

if CURRO:
    NS_PATH ="G:\\fs_namespaces\\prueba_distribuida"
    NS_PATH ="C:\\fs_namespaces\\prueba_distribuida"

else:
    NS_PATH = "/home/augusto/python/notebooks/fs_namespaces/prueba_distribuida"

# %%
import logging
logging.getLogger("distributed_processing").setLevel(logging.DEBUG)
#logging.getLogger("distributed_processing.filesystem_connector").setLevel(logging.DEBUG)

# %%
"""
fs_connector = FileSystemConnector(NS_PATH)
fs_connector.with_watchdog=True
fs_connector.pop_watchdog_timeout = 10

client = Client(DummySerializer(), fs_connector, check_registry="cache")
"""

client = fsclient(NS_PATH)
# Out:
# Client with id: fs_client_2
# Results queue: fs_client_2_responses
# 2026-03-13T16:39:17.249976 Client: fs_client_2 with responses queue: fs_client_2_responses connected

# %%
client.update_registry_cache()

# %%
y = client.rpc_async("add", [1, 0])
# Out:
# 2026-03-13T16:39:19.013954 Client: fs_client_2 sent request with id: fs_client_2:1 to queue: requests_cola_1

# %%
y.get()
# Out:
# 2026-03-13T16:39:19.668899 Client: fs_client_2 received a Single RESULT with id: fs_client_2:1
# 1

# %%
client.check_registry ="always"

try:
    y = client.rpc_async("fake", [1, 0])
except Exception as e:
    print(e)
# Out:
# 'method_queues_fake'

# %%
client.check_registry ="never" # use queue client.default_queue, by default "default"
client.set_default_queue("cola_1")

y = client.rpc_async("fake", [1, 0])

try:
    y.get()
except Exception as e:
    print(e)
# Out:
# 2026-03-13T16:39:23.247750 Client: fs_client_2 sent request with id: fs_client_2:2 to queue: requests_cola_1
# 2026-03-13T16:39:23.397302 Client: fs_client_2 received a Single ERROR with id: fs_client_2:2
# Error -32601 : The method does not exist/is not available.

# %%
client.check_registry ="never"
client.set_default_queue("cola_1")

y = client.rpc_async("fake", [1, 0])

y.safe_get(default="Esto es un error")
# Out:
# 2026-03-13T16:39:29.620009 Client: fs_client_2 sent request with id: fs_client_2:3 to queue: requests_cola_1
# 2026-03-13T16:39:29.813399 Client: fs_client_2 received a Single ERROR with id: fs_client_2:3
# 'Esto es un error'

# %%
client.check_registry ="cache"

# %%
x = client.rpc_async("div", [1, 0])
# Out:
# 2026-03-13T16:39:34.334037 Client: fs_client_2 sent request with id: fs_client_2:4 to queue: requests_cola_1

# %%
try:
    x.get()
except Exception as e:
    print(e)
# Out:
# 2026-03-13T16:39:35.976106 Client: fs_client_2 received a Single ERROR with id: fs_client_2:4
# Error -3260 : Undefined error

# %%
x = client.rpc_sync("div", [1, 0])

# %%
client.rpc_sync("add", [1, 1])
# Out:
# 2026-03-13T16:26:23.247528 Client: fs_client_1 sent request with id: fs_client_1:5 to queue: requests_cola_1
# 2026-03-13T16:26:23.371132 Client: fs_client_1 received a Single RESULT with id: fs_client_1:5
# 2

# %%
def f(x,y): return x + y

y = client.rpc_async_fn(f, [1, 2.0])
# Out:
# 2026-03-13T16:26:23.406330 Client: fs_client_1 sent request with id: fs_client_1:6 to queue: requests_py_eval

# %%
y.get()
# Out:
# 2026-03-13T16:26:23.497877 Client: fs_client_1 received a Single RESULT with id: fs_client_1:6
# 3.0

# %%
client.rpc_sync_fn(f, [3.0, 2.0])
# Out:
# 2026-03-13T16:26:23.863838 Client: fs_client_1 sent request with id: fs_client_1:7 to queue: requests_py_eval
# 2026-03-13T16:26:24.020777 Client: fs_client_1 received a Single RESULT with id: fs_client_1:7
# 5.0

# %%
fs =[]
tp = []
N = 10
for i in range(N):
    fn = random.choice(("add", "mul", "div", "lista", "tupla", "dic"))
    t = (fn, [random.random(),random.random()], {})
    print(t)
    tp.append(t)
    fs.append(client.rpc_async(t[0], t[1]))

t = ("sleep", [10], {})
tp.append(t)
fs.append(client.rpc_async(t[0], t[1]))
# Out:
# 2026-03-13T16:26:24.068213 Client: fs_client_1 sent request with id: fs_client_1:8 to queue: requests_cola_1
# 2026-03-13T16:26:24.111007 Client: fs_client_1 sent request with id: fs_client_1:9 to queue: requests_cola_1
# 2026-03-13T16:26:24.140158 Client: fs_client_1 sent request with id: fs_client_1:10 to queue: requests_cola_1
# 2026-03-13T16:26:24.173920 Client: fs_client_1 sent request with id: fs_client_1:11 to queue: requests_cola_1
# 2026-03-13T16:26:24.206192 Client: fs_client_1 sent request with id: fs_client_1:12 to queue: requests_cola_1
# ('div', [0.37262127156876357, 0.594723273535261], {})
# ('div', [0.9755366882504105, 0.6995847932054393], {})
# ('dic', [0.4491326336668383, 0.8652911523587034], {})
# ('lista', [0.6434064531550804, 0.34785309091690986], {})
# ('dic', [0.35408290827481603, 0.08299937352899589], {})
# ('add', [0.9551058977467745, 0.3193429805076402], {})
# 2026-03-13T16:26:24.238645 Client: fs_client_1 sent request with id: fs_client_1:13 to queue: requests_cola_1
# 2026-03-13T16:26:24.276593 Client: fs_client_1 sent request with id: fs_client_1:14 to queue: requests_cola_1
# 2026-03-13T16:26:24.307638 Client: fs_client_1 sent request with id: fs_client_1:15 to queue: requests_cola_1
# 2026-03-13T16:26:24.349037 Client: fs_client_1 sent request with id: fs_client_1:16 to queue: requests_cola_1
# 2026-03-13T16:26:24.381989 Client: fs_client_1 sent request with id: fs_client_1:17 to queue: requests_cola_1
# 2026-03-13T16:26:24.408988 Client: fs_client_1 sent request with id: fs_client_1:18 to queue: requests_cola_1
# ('mul', [0.8984374384045085, 0.621989073512399], {})
# ('dic', [0.6358902237904387, 0.3635225075047639], {})
# ('lista', [0.48511372398809327, 0.40830737980642473], {})
# ('tupla', [0.4636598998384849, 0.45267603868196893], {})

# %%
resultados = [f.get() for f in fs]
resultados
# Out:
# 2026-03-13T16:26:24.474478 Client: fs_client_1 received a Single RESULT with id: fs_client_1:8
# 2026-03-13T16:26:24.476193 Client: fs_client_1 received a Single RESULT with id: fs_client_1:9
# 2026-03-13T16:26:24.477469 Client: fs_client_1 received a Single RESULT with id: fs_client_1:10
# 2026-03-13T16:26:24.495305 Client: fs_client_1 received a Single RESULT with id: fs_client_1:11
# 2026-03-13T16:26:24.556137 Client: fs_client_1 received a Single RESULT with id: fs_client_1:12
# 2026-03-13T16:26:24.661854 Client: fs_client_1 received a Single RESULT with id: fs_client_1:13
# 2026-03-13T16:26:24.678779 Client: fs_client_1 received a Single RESULT with id: fs_client_1:14
# 2026-03-13T16:26:24.745966 Client: fs_client_1 received a Single RESULT with id: fs_client_1:15
# 2026-03-13T16:26:24.760429 Client: fs_client_1 received a Single RESULT with id: fs_client_1:16
# 2026-03-13T16:26:24.886851 Client: fs_client_1 received a Single RESULT with id: fs_client_1:17
# 2026-03-13T16:26:34.934573 Client: fs_client_1 received a Single RESULT with id: fs_client_1:18
# [0.626545635844653,
#  1.3944509625210442,
#  {'a': 0.4491326336668383, 'b': [0.4491326336668383, 0.8652911523587034]},
#  [0.6434064531550804, 0.34785309091690986],
#  {'a': 0.35408290827481603, 'b': [0.35408290827481603, 0.08299937352899589]},
#  1.2744488782544146,
#  0.5588182699220733,
#  {'a': 0.6358902237904387, 'b': [0.6358902237904387, 0.3635225075047639]},
#  [0.48511372398809327, 0.40830737980642473],
#  (0.4636598998384849, 0.45267603868196893),
#  None]

# %%
fs = client.rpc_multi_async(tp)
# Out:
# 2026-03-13T16:26:34.966981 Client: fs_client_1 sent request with id: fs_client_1:19 to queue: requests_cola_1
# 2026-03-13T16:26:34.988443 Client: fs_client_1 sent request with id: fs_client_1:20 to queue: requests_cola_1
# 2026-03-13T16:26:35.007040 Client: fs_client_1 sent request with id: fs_client_1:21 to queue: requests_cola_1
# 2026-03-13T16:26:35.027514 Client: fs_client_1 sent request with id: fs_client_1:22 to queue: requests_cola_1
# 2026-03-13T16:26:35.047336 Client: fs_client_1 sent request with id: fs_client_1:23 to queue: requests_cola_1
# 2026-03-13T16:26:35.071124 Client: fs_client_1 sent request with id: fs_client_1:24 to queue: requests_cola_1
# 2026-03-13T16:26:35.092239 Client: fs_client_1 sent request with id: fs_client_1:25 to queue: requests_cola_1
# 2026-03-13T16:26:35.123146 Client: fs_client_1 sent request with id: fs_client_1:26 to queue: requests_cola_1
# 2026-03-13T16:26:35.145296 Client: fs_client_1 sent request with id: fs_client_1:27 to queue: requests_cola_1
# 2026-03-13T16:26:35.165902 Client: fs_client_1 sent request with id: fs_client_1:28 to queue: requests_cola_1
# 2026-03-13T16:26:35.193332 Client: fs_client_1 sent request with id: fs_client_1:29 to queue: requests_cola_1

# %%
# AsynResult.status updates the information every time it is called.
# 'PENDING' state should be assumed as transitory. 
# If there are responses available in the queue or in the cache 
# status or pending() updates the AsyncResult object.

[f.status for f in fs]
# Out:
# 2026-03-13T16:26:35.250309 Client: fs_client_1 received a Single RESULT with id: fs_client_1:19
# 2026-03-13T16:26:35.251591 Client: fs_client_1 received a Single RESULT with id: fs_client_1:20
# 2026-03-13T16:26:35.252612 Client: fs_client_1 received a Single RESULT with id: fs_client_1:21
# 2026-03-13T16:26:35.267480 Client: fs_client_1 received a Single RESULT with id: fs_client_1:22
# 2026-03-13T16:26:35.286670 Client: fs_client_1 received a Single RESULT with id: fs_client_1:23
# ['OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING']

# %%
client.wait_responses(timeout=2)
# Out:
# 2026-03-13T16:26:35.413652 Client: fs_client_1 received a Single RESULT with id: fs_client_1:24
# 2026-03-13T16:26:35.426986 Client: fs_client_1 received a Single RESULT with id: fs_client_1:25
# 2026-03-13T16:26:35.483110 Client: fs_client_1 received a Single RESULT with id: fs_client_1:26
# 2026-03-13T16:26:35.582473 Client: fs_client_1 received a Single RESULT with id: fs_client_1:27
# 2026-03-13T16:26:35.598249 Client: fs_client_1 received a Single RESULT with id: fs_client_1:28
# ['fs_client_1:29']

# %%
[f.status for f in fs]
# Out:
# ['OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'PENDING']

# %%
client.wait_responses()
# Out:
# 2026-03-13T16:26:45.636293 Client: fs_client_1 received a Single RESULT with id: fs_client_1:29
# []

# %%
# AsynResult.status updates information

[f.status for f in fs]
# Out:
# ['OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK']

# %%
try:
    client.wait_responses(["kk", "qq"])
except ValueError as e:
    print(e)
# Out:
# wait_responses: ['kk', 'qq'] neither in responses nor in pending.

# %%
client._update_cache_with_all_available_responses()

# %%
client.pending
# Out:
# {}

# %%
[f.get() for f in fs]
# Out:
# [0.626545635844653,
#  1.3944509625210442,
#  {'a': 0.4491326336668383, 'b': [0.4491326336668383, 0.8652911523587034]},
#  [0.6434064531550804, 0.34785309091690986],
#  {'a': 0.35408290827481603, 'b': [0.35408290827481603, 0.08299937352899589]},
#  1.2744488782544146,
#  0.5588182699220733,
#  {'a': 0.6358902237904387, 'b': [0.6358902237904387, 0.3635225075047639]},
#  [0.48511372398809327, 0.40830737980642473],
#  (0.4636598998384849, 0.45267603868196893),
#  None]

# %%
fs = client.rpc_batch_async(tp)
# Out:
# 2026-03-13T16:26:45.820097 Client: fs_client_1 sent batch request with 11 requests to queue: requests_cola_1

# %%
[f.get() for f in fs]
# Out:
# 2026-03-13T16:26:56.043253 Client: fs_client_1 received a Batch Response with 11 items
# 2026-03-13T16:26:56.044153 Client: fs_client_1 processed a RESULT with id: fs_client_1:30 from BATCH response
# 2026-03-13T16:26:56.044623 Client: fs_client_1 processed a RESULT with id: fs_client_1:31 from BATCH response
# 2026-03-13T16:26:56.045152 Client: fs_client_1 processed a RESULT with id: fs_client_1:32 from BATCH response
# 2026-03-13T16:26:56.045737 Client: fs_client_1 processed a RESULT with id: fs_client_1:33 from BATCH response
# 2026-03-13T16:26:56.046390 Client: fs_client_1 processed a RESULT with id: fs_client_1:34 from BATCH response
# 2026-03-13T16:26:56.047052 Client: fs_client_1 processed a RESULT with id: fs_client_1:35 from BATCH response
# 2026-03-13T16:26:56.047723 Client: fs_client_1 processed a RESULT with id: fs_client_1:36 from BATCH response
# 2026-03-13T16:26:56.048199 Client: fs_client_1 processed a RESULT with id: fs_client_1:37 from BATCH response
# 2026-03-13T16:26:56.048686 Client: fs_client_1 processed a RESULT with id: fs_client_1:38 from BATCH response
# 2026-03-13T16:26:56.049173 Client: fs_client_1 processed a RESULT with id: fs_client_1:39 from BATCH response
# 2026-03-13T16:26:56.049711 Client: fs_client_1 processed a RESULT with id: fs_client_1:40 from BATCH response
# [0.626545635844653,
#  1.3944509625210442,
#  {'a': 0.4491326336668383, 'b': [0.4491326336668383, 0.8652911523587034]},
#  [0.6434064531550804, 0.34785309091690986],
#  {'a': 0.35408290827481603, 'b': [0.35408290827481603, 0.08299937352899589]},
#  1.2744488782544146,
#  0.5588182699220733,
#  {'a': 0.6358902237904387, 'b': [0.6358902237904387, 0.3635225075047639]},
#  [0.48511372398809327, 0.40830737980642473],
#  (0.4636598998384849, 0.45267603868196893),
#  None]

# %%
client.rpc_batch_sync(tp)
# Out:
# 2026-03-13T16:26:56.084880 Client: fs_client_1 sent batch request with 11 requests to queue: requests_cola_1
# 2026-03-13T16:27:06.296328 Client: fs_client_1 received a Batch Response with 11 items
# 2026-03-13T16:27:06.297006 Client: fs_client_1 processed a RESULT with id: fs_client_1:41 from BATCH response
# 2026-03-13T16:27:06.297392 Client: fs_client_1 processed a RESULT with id: fs_client_1:42 from BATCH response
# 2026-03-13T16:27:06.297738 Client: fs_client_1 processed a RESULT with id: fs_client_1:43 from BATCH response
# 2026-03-13T16:27:06.298178 Client: fs_client_1 processed a RESULT with id: fs_client_1:44 from BATCH response
# 2026-03-13T16:27:06.298594 Client: fs_client_1 processed a RESULT with id: fs_client_1:45 from BATCH response
# 2026-03-13T16:27:06.299902 Client: fs_client_1 processed a RESULT with id: fs_client_1:46 from BATCH response
# 2026-03-13T16:27:06.300346 Client: fs_client_1 processed a RESULT with id: fs_client_1:47 from BATCH response
# 2026-03-13T16:27:06.300755 Client: fs_client_1 processed a RESULT with id: fs_client_1:48 from BATCH response
# 2026-03-13T16:27:06.301261 Client: fs_client_1 processed a RESULT with id: fs_client_1:49 from BATCH response
# 2026-03-13T16:27:06.301767 Client: fs_client_1 processed a RESULT with id: fs_client_1:50 from BATCH response
# 2026-03-13T16:27:06.302280 Client: fs_client_1 processed a RESULT with id: fs_client_1:51 from BATCH response
# [0.626545635844653,
#  1.3944509625210442,
#  {'a': 0.4491326336668383, 'b': [0.4491326336668383, 0.8652911523587034]},
#  [0.6434064531550804, 0.34785309091690986],
#  {'a': 0.35408290827481603, 'b': [0.35408290827481603, 0.08299937352899589]},
#  1.2744488782544146,
#  0.5588182699220733,
#  {'a': 0.6358902237904387, 'b': [0.6358902237904387, 0.3635225075047639]},
#  [0.48511372398809327, 0.40830737980642473],
#  (0.4636598998384849, 0.45267603868196893),
#  None]

# %%
fs =[]
tp = []
N = 10
for i in range(N):
    fn = random.choice(("add", "mul", "div", "fake"))
    t = (fn, [random.random(),random.random()], {})
    print(t)
    tp.append(t)
# Out:
# ('add', [0.3665018593228295, 0.7560287194012497], {})
# ('fake', [0.9906592982223549, 0.35793317450643936], {})
# ('add', [0.5019017945120291, 0.10181026184095154], {})
# ('fake', [0.15256696327502672, 0.7501914941148273], {})
# ('div', [0.2241541215827385, 0.7144538729281138], {})
# ('div', [0.4478752189711923, 0.6684652446069718], {})
# ('div', [0.2493321936080617, 0.9657947663435411], {})
# ('mul', [0.020125042167797202, 0.8360014338265099], {})
# ('add', [0.08121065864303534, 0.9218815141143544], {})
# ('div', [0.07582409779505872, 0.4650930259276165], {})

# %%
tp
# Out:
# [('add', [0.3665018593228295, 0.7560287194012497], {}),
#  ('fake', [0.9906592982223549, 0.35793317450643936], {}),
#  ('add', [0.5019017945120291, 0.10181026184095154], {}),
#  ('fake', [0.15256696327502672, 0.7501914941148273], {}),
#  ('div', [0.2241541215827385, 0.7144538729281138], {}),
#  ('div', [0.4478752189711923, 0.6684652446069718], {}),
#  ('div', [0.2493321936080617, 0.9657947663435411], {}),
#  ('mul', [0.020125042167797202, 0.8360014338265099], {}),
#  ('add', [0.08121065864303534, 0.9218815141143544], {}),
#  ('div', [0.07582409779505872, 0.4650930259276165], {})]

# %%
client.check_registry ="never"
client.set_default_queue("cola_1")

fs = client.rpc_batch_async(tp)
# Out:
# 2026-03-13T16:27:06.398278 Client: fs_client_1 sent batch request with 10 requests to queue: requests_cola_1

# %%
[f.safe_get() for f in fs]
# Out:
# 2026-03-13T16:27:06.562956 Client: fs_client_1 received a Batch Response with 10 items
# 2026-03-13T16:27:06.563809 Client: fs_client_1 processed a RESULT with id: fs_client_1:52 from BATCH response
# 2026-03-13T16:27:06.564465 Client: fs_client_1 processed a ERROR with id: fs_client_1:53 from BATCH response
# 2026-03-13T16:27:06.565141 Client: fs_client_1 processed a RESULT with id: fs_client_1:54 from BATCH response
# 2026-03-13T16:27:06.565870 Client: fs_client_1 processed a ERROR with id: fs_client_1:55 from BATCH response
# 2026-03-13T16:27:06.566562 Client: fs_client_1 processed a RESULT with id: fs_client_1:56 from BATCH response
# 2026-03-13T16:27:06.567205 Client: fs_client_1 processed a RESULT with id: fs_client_1:57 from BATCH response
# 2026-03-13T16:27:06.567615 Client: fs_client_1 processed a RESULT with id: fs_client_1:58 from BATCH response
# 2026-03-13T16:27:06.568082 Client: fs_client_1 processed a RESULT with id: fs_client_1:59 from BATCH response
# 2026-03-13T16:27:06.568480 Client: fs_client_1 processed a RESULT with id: fs_client_1:60 from BATCH response
# 2026-03-13T16:27:06.568974 Client: fs_client_1 processed a RESULT with id: fs_client_1:61 from BATCH response
# [1.1225305787240791,
#  None,
#  0.6037120563529806,
#  None,
#  0.31374190843709265,
#  0.6700052434805691,
#  0.2581627094046316,
#  0.016824564108097434,
#  1.0030921727573898,
#  0.163029960820912]

# %%
client.responses
# Out:
# {}

# %%
client.check_registry ="cache"

# %%
try:
    x = client.rpc_batch_sync(tp, timeout=5)
except Exception as e:
    print(e)
# Out:
# Method fake does not exist/is not available.

# %%
try:    
    x = client.rpc_batch_sync(tp, timeout=5)
except Exception as e:
    print(e)
# Out:
# Method fake does not exist/is not available.

# %%
client.check_registry="never"
client.set_default_queue("cola_1")

x = client.rpc_async("kk", [1, 0])
# Out:
# 2026-03-13T16:27:06.734571 Client: fs_client_1 sent request with id: fs_client_1:62 to queue: requests_cola_1

# %%
try:
    x.get()
except Exception as e:
    print(e)
# Out:
# 2026-03-13T16:27:06.861505 Client: fs_client_1 received a Single ERROR with id: fs_client_1:62
# Error -32601 : The method does not exist/is not available.

# %%
y = client.rpc_async("add", [1, 0])
# Out:
# 2026-03-13T16:27:06.897634 Client: fs_client_1 sent request with id: fs_client_1:63 to queue: requests_cola_1

# %%
y.get(5)
# Out:
# 2026-03-13T16:27:07.054502 Client: fs_client_1 received a Single RESULT with id: fs_client_1:63
# 1

# %%
def f(x,y): return x + y

client.check_registry = "never" # "never" use queue "default" don't work for rpc_async_fn or rpc_sync_fn 
y = client.rpc_async_fn(f, [1, 2.0])
try:
    print(y.get())
except Exception as e:
    print(e)
# Out:
# 2026-03-13T16:27:07.086501 Client: fs_client_1 sent request with id: fs_client_1:64 to queue: requests_cola_1
# 2026-03-13T16:27:07.316671 Client: fs_client_1 received a Single ERROR with id: fs_client_1:64
# Error -32601 : The method does not exist/is not available.

# %%
client.check_registry = "cache"
y = client.rpc_async_fn(f, [1, 2.0])
# Out:
# 2026-03-13T16:27:07.350085 Client: fs_client_1 sent request with id: fs_client_1:65 to queue: requests_py_eval

# %%
y.get()
# Out:
# 2026-03-13T16:27:07.502750 Client: fs_client_1 received a Single RESULT with id: fs_client_1:65
# 3.0

# %%
[k for k in client.responses.keys()]
# Out:
# []

# %%
client.clean_used()

# %%
[k for k in client.responses.keys()]
# Out:
# []

# %%
resultados
# Out:
# [0.626545635844653,
#  1.3944509625210442,
#  {'a': 0.4491326336668383, 'b': [0.4491326336668383, 0.8652911523587034]},
#  [0.6434064531550804, 0.34785309091690986],
#  {'a': 0.35408290827481603, 'b': [0.35408290827481603, 0.08299937352899589]},
#  1.2744488782544146,
#  0.5588182699220733,
#  {'a': 0.6358902237904387, 'b': [0.6358902237904387, 0.3635225075047639]},
#  [0.48511372398809327, 0.40830737980642473],
#  (0.4636598998384849, 0.45267603868196893),
#  None]

# %%
client.rpc_sync_fn(print, ["hola"])
# Out:
# 2026-03-13T16:27:07.697581 Client: fs_client_1 sent request with id: fs_client_1:66 to queue: requests_py_eval
# 2026-03-13T16:27:07.827147 Client: fs_client_1 received a Single RESULT with id: fs_client_1:66

# %%
fs =[]
tp = []
N = 10
for i in range(N):
    fn = random.choice(("sleep", "sleep"))
    t = (fn, [15], {})
    print(t)
    tp.append(t)
# Out:
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})

# %%
client.check_registry="never"
fs = client.rpc_multi_async(tp, retry=True)
# Out:
# 2026-03-13T16:27:07.887690 Client: fs_client_1 sent request with id: fs_client_1:67 to queue: requests_cola_1
# 2026-03-13T16:27:07.907423 Client: fs_client_1 sent request with id: fs_client_1:68 to queue: requests_cola_1
# 2026-03-13T16:27:07.925195 Client: fs_client_1 sent request with id: fs_client_1:69 to queue: requests_cola_1
# 2026-03-13T16:27:07.943149 Client: fs_client_1 sent request with id: fs_client_1:70 to queue: requests_cola_1
# 2026-03-13T16:27:08.398914 Client: fs_client_1 sent request with id: fs_client_1:71 to queue: requests_cola_1
# 2026-03-13T16:27:08.426168 Client: fs_client_1 sent request with id: fs_client_1:72 to queue: requests_cola_1
# 2026-03-13T16:27:08.443738 Client: fs_client_1 sent request with id: fs_client_1:73 to queue: requests_cola_1
# 2026-03-13T16:27:08.462164 Client: fs_client_1 sent request with id: fs_client_1:74 to queue: requests_cola_1
# 2026-03-13T16:27:08.480837 Client: fs_client_1 sent request with id: fs_client_1:75 to queue: requests_cola_1
# 2026-03-13T16:27:08.499646 Client: fs_client_1 sent request with id: fs_client_1:76 to queue: requests_cola_1

# %%
from time import time

def gather(arl, timeout=None, step=5, max_dts=0):
    # Update to reset delta times
    pending_ars = [ar for ar in arl if not(ar.ok() or ar.failed())] 
    pending_ids = [ar.id for ar in pending_ars]
    if fs[0]._client.wait_responses(pending_ids, timeout=0) == []:
        return

    N = len(arl)

    max_dts = max_dts

    t_0 = time()

    i = 0
    # ok() and failed() don't update.
    # pending() updates, every time is called, all the ids 
    # that have a response available in the queue 
    pending_ars = [ar for ar in arl if not(ar.ok() or ar.failed())]
    pending_ars0= pending_ars
    pending_ids = [ar.id for ar in pending_ars]
    t_prev = time()
    n_pending_prev = len(pending_ars)
    n_pending_0 = n_pending_prev    
    while (time() - t_0) <= timeout:
        try:
            if fs[0]._client.wait_responses(pending_ids, timeout=5) == []:
                return
        except TimeoutError:
            pass
        dts = [ar.finished_time - t_0 for ar in pending_ars0 if (ar.ok() or ar.failed())]
        if len(dts)>0:
            #max_dts = max(max_dts, max(dts))
            max_dts = max(dts)    
        pending_ars = [ar for ar in arl if not(ar.ok() or ar.failed())] 
        pending_ids = [ar.id for ar in pending_ars]
        if len(pending_ars) < n_pending_prev:
            t_prev = time()
            n_pending_prev = len(pending_ars)  

        avg =  (time()-t_0)/(n_pending_0 -len(pending_ars)) if (n_pending_0 -len(pending_ars))>0 else 0

        print(f"{i}: seconds {time()-t_0}s, AR recovered {N-len(pending_ars)}, \
                AR left {len(pending_ars)}, max delta {max_dts}, avg {avg}")
        i += 0

# %%
gather(fs, 30, 5)
# Out:
# 0: seconds 5.184253692626953s, AR recovered 0,                 AR left 10, max delta 0, avg 0
# 0: seconds 10.339864253997803s, AR recovered 0,                 AR left 10, max delta 0, avg 0
# 2026-03-13T16:27:23.078847 Client: fs_client_1 received a Single RESULT with id: fs_client_1:67
# 0: seconds 15.423064947128296s, AR recovered 1,                 AR left 9, max delta 14.469173431396484, avg 15.423063278198242
# 0: seconds 20.584538221359253s, AR recovered 1,                 AR left 9, max delta 14.469173431396484, avg 20.5845365524292
# 0: seconds 25.66038966178894s, AR recovered 1,                 AR left 9, max delta 14.469173431396484, avg 25.660388231277466
# 2026-03-13T16:27:38.088426 Client: fs_client_1 received a Single RESULT with id: fs_client_1:68
# 0: seconds 30.801668643951416s, AR recovered 2,                 AR left 8, max delta 29.478752851486206, avg 15.40083372592926

# %%
[f.status for f in fs]
# Out:
# ['OK',
#  'OK',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING']

# %%
[(time() if f.finished_time is None else f.finished_time) -f.creation_time for f in fs]
# Out:
# [15.189860820770264,
#  30.180342435836792,
#  31.526453971862793,
#  31.50845456123352,
#  31.052572011947632,
#  31.02544927597046,
#  31.00795078277588,
#  30.98945665359497,
#  30.970808744430542,
#  30.952016353607178]

# %%
[f.finished_time for f in fs]
# Out:
# [1773415643.0788429,
#  1773415658.0884223,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
client.pending
# Out:
# {'fs_client_1:69': 1773415627.925813,
#  'fs_client_1:70': 1773415627.9438136,
#  'fs_client_1:71': 1773415628.3996956,
#  'fs_client_1:72': 1773415628.4268198,
#  'fs_client_1:73': 1773415628.4443188,
#  'fs_client_1:74': 1773415628.4628117,
#  'fs_client_1:75': 1773415628.4814615,
#  'fs_client_1:76': 1773415628.5002542}

# %%
fs[3].status
# Out:
# 'PENDING'

# %%
fs[0].retry()
# Out:
# 2026-03-13T16:27:39.566809 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:67 already received.

# %%
[f.retry() for f in fs if f.ok is not None]
# Out:
# 2026-03-13T16:36:50.226261 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:67 already received.
# 2026-03-13T16:36:50.227221 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:68 already received.
# 2026-03-13T16:36:50.228015 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:69 already received.
# 2026-03-13T16:36:50.228711 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:70 already received.
# 2026-03-13T16:36:50.229352 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:71 already received.
# 2026-03-13T16:36:50.230075 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:72 already received.
# 2026-03-13T16:36:50.230989 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:73 already received.
# 2026-03-13T16:36:50.231618 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:74 already received.
# 2026-03-13T16:36:50.232286 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:75 already received.
# 2026-03-13T16:36:50.232955 Client: fs_client_1 Not Retrying: Response to Request with id: fs_client_1:76 already received.
# [None, None, None, None, None, None, None, None, None, None]

# %%
import datetime

# %%
datetime.datetime.now().isoformat()
# Out:
# '2026-03-13T16:36:50.289887'

# %%
from datetime import datetime

# %%
client.check_registry="always"
client.all_queues_for_method("info")
# Out:
# ['requests_fs_server_1']

# %%
client.connector.all_queues_for_method("info")
# Out:
# ['requests_fs_server_1']

# %%
client.update_registry_cache()

# %%
client.check_registry="Never"
client.all_queues_for_method("hola")
# Out:
# ['requests_cola_1']

# %%
client.check_registry="always"
a = client.rpc_async("info")
# Out:
# 2026-03-13T16:37:45.166015 Client: fs_client_1 sent request with id: fs_client_1:77 to queue: requests_fs_server_1

# %%
client.rpc_sync("div", [2,1], timeout=10)
# Out:
# 2026-03-13T16:37:45.196821 Client: fs_client_1 sent request with id: fs_client_1:78 to queue: requests_cola_1
# 2026-03-13T16:37:45.315603 Client: fs_client_1 received a Single RESULT with id: fs_client_1:78
# 2.0

# %%
x = a.get()
# Out:
# 2026-03-13T16:37:45.345278 Client: fs_client_1 received a Single RESULT with id: fs_client_1:77

# %%
client.registry
# Out:
# {'add': ['requests_cola_1'],
#  'dic': ['requests_cola_1'],
#  'div': ['requests_cola_1'],
#  'eval_py_function': ['requests_py_eval'],
#  'info': ['requests_fs_server_1'],
#  'lista': ['requests_cola_1'],
#  'mul': ['requests_cola_1'],
#  'sleep': ['requests_cola_1'],
#  'tupla': ['requests_cola_1']}

# %%
def registry_one_step(x):
    worker_id = x[0]
    registry = {}
    for queue, methods in x[1].items():
        for method in methods:
            if method in registry:
                registry[method].append(queue)
            else:
                registry[method] = [queue]
    return registry 

def queues_workers_one_step(x):
    worker_id = x[0]
    registry = {}
    for queue in x[1]:
        if queue in registry:
            registry[queue].append(worker_id)
        else:
            registry[queue] = [worker_id]
    return registry 

def all_workers_for_queue():
    # all requests queues for "info" method
    # One queue per worker

    rr = {}
    qq = {}
    all_worker_queues = client.connector.all_queues_for_method("info")
    for worker in all_worker_queues:
        try:
            x = client.rpc_sync("info", timeout=10)
        except TimeoutError:
            x = None
        
        if x is not None:
            for method, qs in registry_one_step(x).items():
                if method not in rr:
                    rr[method] = qs
                else:
                    rr[method] += qs
            for q, ws in queues_workers_one_step(x).items():
                if q not in qq:
                    qq[q] = ws
                else:
                    qq[q] += ws
    return rr, qq

# %%
registry_one_step(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 registry_one_step(x)
#
# Cell In[80], line 6, in registry_one_step(x)
#       4 for queue, methods in x[1].items():
#       5     for method in methods:
# ----> 6         if method in registry:
#       7             registry[method].append(queue)
#       8         else:
#
# TypeError: unhashable type: 'dict'

# %%
queues_workers_one_step(x)
# Out:
# {'requests_fs_server_2': ['fs_server_2'],
#  'requests_cola_1': ['fs_server_2'],
#  'requests_cola_2': ['fs_server_2'],
#  'requests_py_eval': ['fs_server_2']}

# %%
r, q = all_workers_for_queue()
# Out:
# 2026-03-13T16:38:56.615579 Client: fs_client_1 sent request with id: fs_client_1:79 to queue: requests_fs_server_1
# 2026-03-13T16:38:56.746920 Client: fs_client_1 received a Single RESULT with id: fs_client_1:79
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 r, q = all_workers_for_queue()
#
# Cell In[80], line 36, in all_workers_for_queue()
#      33     x = None
#      35 if x is not None:
# ---> 36     for method, qs in registry_one_step(x).items():
#      37         if method not in rr:
#      38             rr[method] = qs
#
# Cell In[80], line 6, in registry_one_step(x)
#       4 for queue, methods in x[1].items():
#       5     for method in methods:
# ----> 6         if method in registry:
#       7             registry[method].append(queue)
#       8         else:
#
# TypeError: unhashable type: 'dict'

# %%
r
# Out:
# {'info': ['requests_fs_server_1', 'requests_fs_server_2'],
#  'add': ['requests_cola_1', 'requests_cola_1'],
#  'mul': ['requests_cola_1', 'requests_cola_1'],
#  'div': ['requests_cola_1', 'requests_cola_1'],
#  'lista': ['requests_cola_1', 'requests_cola_1'],
#  'tupla': ['requests_cola_1', 'requests_cola_1'],
#  'dic': ['requests_cola_1', 'requests_cola_1'],
#  'sleep': ['requests_cola_1', 'requests_cola_1'],
#  'hola': ['requests_cola_2', 'requests_cola_2'],
#  'eval_py_function': ['requests_py_eval', 'requests_py_eval']}

# %%
q
# Out:
# {'requests_fs_server_1': ['fs_server_1'],
#  'requests_cola_1': ['fs_server_1', 'fs_server_2'],
#  'requests_cola_2': ['fs_server_1', 'fs_server_2'],
#  'requests_py_eval': ['fs_server_1', 'fs_server_2'],
#  'requests_fs_server_2': ['fs_server_2']}

# %%
t = (1,2,3,4)

# %%
t[:6]
# Out:
# (1, 2, 3, 4)

# %%
t[:5]
# Out:
# (1, 2, 3, 4)
