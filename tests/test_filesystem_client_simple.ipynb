# %%
import random

from distributed_processing.utils import fsclient

# %%
CURRO = True

if CURRO:
    NS_PATH ="G:\\fs_namespaces\\prueba_distribuida"
    NS_PATH ="C:\\fs_namespaces\\prueba_distribuida"

else:
    NS_PATH = "/home/augusto/python/notebooks/fs_namespaces/prueba_distribuida"

# %%
import logging
logging.getLogger("distributed_processing").setLevel(logging.DEBUG)
#logging.getLogger("distributed_processing.filesystem_connector").setLevel(logging.DEBUG)

# %%
"""
fs_connector = FileSystemConnector(NS_PATH)
fs_connector.with_watchdog=True
fs_connector.pop_watchdog_timeout = 10

client = Client(DummySerializer(), fs_connector, check_registry="cache")
"""

client = fsclient(NS_PATH)
# Out:
# 2026-02-24T16:57:47.506657 registry_lock set in C:\fs_namespaces\prueba_distribuida\ud_variables
# 2026-02-24T16:57:47.548601 registry_lock unset in C:\fs_namespaces\prueba_distribuida\ud_variables
# 2026-02-24T16:57:47.549917 nclients_lock set in C:\fs_namespaces\prueba_distribuida\ud_variables
# 2026-02-24T16:57:47.581833 nclients_lock unset in C:\fs_namespaces\prueba_distribuida\ud_variables
# Client with id: fs_client_2
# Results queue: fs_client_2_responses
# 2026-02-24T16:57:47.583673 Client: fs_client_2 with responses queue: fs_client_2_responses connected

# %%
client.update_registry_cache()
# Out:
# 2026-02-24T16:57:47.592067 registry_lock set in C:\fs_namespaces\prueba_distribuida\ud_variables
# 2026-02-24T16:57:47.601836 registry_lock unset in C:\fs_namespaces\prueba_distribuida\ud_variables

# %%
y = client.rpc_async("add", [1, 0])
# Out:
# 2026-02-24T16:57:47.639641 Client: fs_client_2 sent request with id: fs_client_2:1 to queue: requests_cola_1

# %%
y.get()
# Out:
# 2026-02-24T16:57:47.779974 Client: fs_client_2 received a Single RESULT with id: fs_client_2:1
# 1

# %%
client.check_registry ="always"

try:
    y = client.rpc_async("fake", [1, 0])
except Exception as e:
    print(e)
# Out:
# 'method_queues_fake'

# %%
client.check_registry ="never" # use queue client.default_queue, by default "default"
client.set_default_queue("cola_1")

y = client.rpc_async("fake", [1, 0])

try:
    y.get()
except Exception as e:
    print(e)
# Out:
# 2026-02-24T16:57:47.855820 Client: fs_client_2 sent request with id: fs_client_2:2 to queue: requests_cola_1
# 2026-02-24T16:57:48.036245 Client: fs_client_2 received a Single ERROR with id: fs_client_2:2
# Error -32601 : The method does not exist/is not available.

# %%
client.check_registry ="never"
client.set_default_queue("cola_1")

y = client.rpc_async("fake", [1, 0])

y.safe_get(default="Esto es un error")
# Out:
# 2026-02-24T16:57:48.083991 Client: fs_client_2 sent request with id: fs_client_2:3 to queue: requests_cola_1
# 2026-02-24T16:57:48.215967 Client: fs_client_2 received a Single ERROR with id: fs_client_2:3
# 'Esto es un error'

# %%
client.check_registry ="cache"

# %%
x = client.rpc_async("div", [1, 0])
# Out:
# 2026-02-24T16:57:48.276120 Client: fs_client_2 sent request with id: fs_client_2:4 to queue: requests_cola_1

# %%
try:
    x.get()
except Exception as e:
    print(e)
# Out:
# 2026-02-24T16:57:48.365822 Client: fs_client_2 received a Single ERROR with id: fs_client_2:4
# Error -3260 : Undefined error

# %%
client.rpc_sync("add", [1, 1])
# Out:
# 2026-02-24T16:57:48.401544 Client: fs_client_2 sent request with id: fs_client_2:5 to queue: requests_cola_1
# 2026-02-24T16:57:48.562815 Client: fs_client_2 received a Single RESULT with id: fs_client_2:5
# 2

# %%
def f(x,y): return x + y

y = client.rpc_async_fn(f, [1, 2.0])
# Out:
# 2026-02-24T16:57:48.621702 Client: fs_client_2 sent request with id: fs_client_2:6 to queue: requests_py_eval

# %%
y.get()
# Out:
# 2026-02-24T16:57:48.773828 Client: fs_client_2 received a Single RESULT with id: fs_client_2:6
# 3.0

# %%
client.rpc_sync_fn(f, [3.0, 2.0])
# Out:
# 2026-02-24T16:57:48.812403 Client: fs_client_2 sent request with id: fs_client_2:7 to queue: requests_py_eval
# 2026-02-24T16:57:49.019501 Client: fs_client_2 received a Single RESULT with id: fs_client_2:7
# 5.0

# %%
fs =[]
tp = []
N = 10
for i in range(N):
    fn = random.choice(("add", "mul", "div", "lista", "tupla", "dic"))
    t = (fn, [random.random(),random.random()], {})
    print(t)
    tp.append(t)
    fs.append(client.rpc_async(t[0], t[1]))

t = ("sleep", [10], {})
tp.append(t)
fs.append(client.rpc_async(t[0], t[1]))
# Out:
# 2026-02-24T16:57:49.052310 Client: fs_client_2 sent request with id: fs_client_2:8 to queue: requests_cola_1
# 2026-02-24T16:57:49.082717 Client: fs_client_2 sent request with id: fs_client_2:9 to queue: requests_cola_1
# 2026-02-24T16:57:49.101668 Client: fs_client_2 sent request with id: fs_client_2:10 to queue: requests_cola_1
# 2026-02-24T16:57:49.119499 Client: fs_client_2 sent request with id: fs_client_2:11 to queue: requests_cola_1
# 2026-02-24T16:57:49.139057 Client: fs_client_2 sent request with id: fs_client_2:12 to queue: requests_cola_1
# 2026-02-24T16:57:49.160257 Client: fs_client_2 sent request with id: fs_client_2:13 to queue: requests_cola_1
# 2026-02-24T16:57:49.181325 Client: fs_client_2 sent request with id: fs_client_2:14 to queue: requests_cola_1
# 2026-02-24T16:57:49.202291 Client: fs_client_2 sent request with id: fs_client_2:15 to queue: requests_cola_1
# 2026-02-24T16:57:49.224003 Client: fs_client_2 sent request with id: fs_client_2:16 to queue: requests_cola_1
# ('mul', [0.4173774689721823, 0.70760492440506], {})
# ('lista', [0.5621065916950627, 0.899602866176034], {})
# ('mul', [0.10087127174147426, 0.36293705472215865], {})
# ('mul', [0.7536325546359076, 0.6902338027946059], {})
# ('add', [0.06897962876945496, 0.2293538226118217], {})
# ('lista', [0.7017459995498269, 0.1797879442681053], {})
# ('mul', [0.07654898824554879, 0.4202100772142935], {})
# ('add', [0.43530259973221763, 0.13444947070784297], {})
# ('add', [0.003534312925471239, 0.9367089962891688], {})
# ('dic', [0.6488811970352936, 0.719714747619113], {})
# 2026-02-24T16:57:49.245941 Client: fs_client_2 sent request with id: fs_client_2:17 to queue: requests_cola_1
# 2026-02-24T16:57:49.268021 Client: fs_client_2 sent request with id: fs_client_2:18 to queue: requests_cola_1

# %%
resultados = [f.get() for f in fs]
resultados
# Out:
# 2026-02-24T16:57:49.299415 Client: fs_client_2 received a Single RESULT with id: fs_client_2:8
# 2026-02-24T16:57:49.300079 Client: fs_client_2 received a Single RESULT with id: fs_client_2:9
# 2026-02-24T16:57:49.313494 Client: fs_client_2 received a Single RESULT with id: fs_client_2:10
# 2026-02-24T16:57:49.421177 Client: fs_client_2 received a Single RESULT with id: fs_client_2:11
# 2026-02-24T16:57:49.444279 Client: fs_client_2 received a Single RESULT with id: fs_client_2:12
# 2026-02-24T16:57:49.486837 Client: fs_client_2 received a Single RESULT with id: fs_client_2:13
# 2026-02-24T16:57:49.610650 Client: fs_client_2 received a Single RESULT with id: fs_client_2:14
# 2026-02-24T16:57:49.638014 Client: fs_client_2 received a Single RESULT with id: fs_client_2:15
# 2026-02-24T16:57:49.638842 Client: fs_client_2 received a Single RESULT with id: fs_client_2:16
# 2026-02-24T16:57:49.653096 Client: fs_client_2 received a Single RESULT with id: fs_client_2:17
# 2026-02-24T16:57:59.761008 Client: fs_client_2 received a Single RESULT with id: fs_client_2:18
# [0.2953383523804363,
#  [0.5621065916950627, 0.899602866176034],
#  0.03660992227192918,
#  0.5201826640961561,
#  0.29833345138127665,
#  [0.7017459995498269, 0.1797879442681053],
#  0.0321666562613381,
#  0.5697520704400606,
#  0.94024330921464,
#  {'a': 0.6488811970352936, 'b': [0.6488811970352936, 0.719714747619113]},
#  None]

# %%
fs = client.rpc_multi_async(tp)
# Out:
# 2026-02-24T16:57:59.795243 Client: fs_client_2 sent request with id: fs_client_2:19 to queue: requests_cola_1
# 2026-02-24T16:57:59.814564 Client: fs_client_2 sent request with id: fs_client_2:20 to queue: requests_cola_1
# 2026-02-24T16:57:59.833987 Client: fs_client_2 sent request with id: fs_client_2:21 to queue: requests_cola_1
# 2026-02-24T16:57:59.857266 Client: fs_client_2 sent request with id: fs_client_2:22 to queue: requests_cola_1
# 2026-02-24T16:57:59.880639 Client: fs_client_2 sent request with id: fs_client_2:23 to queue: requests_cola_1
# 2026-02-24T16:57:59.899472 Client: fs_client_2 sent request with id: fs_client_2:24 to queue: requests_cola_1
# 2026-02-24T16:57:59.918077 Client: fs_client_2 sent request with id: fs_client_2:25 to queue: requests_cola_1
# 2026-02-24T16:57:59.941643 Client: fs_client_2 sent request with id: fs_client_2:26 to queue: requests_cola_1
# 2026-02-24T16:57:59.979942 Client: fs_client_2 sent request with id: fs_client_2:27 to queue: requests_cola_1
# 2026-02-24T16:58:00.010616 Client: fs_client_2 sent request with id: fs_client_2:28 to queue: requests_cola_1
# 2026-02-24T16:58:00.044647 Client: fs_client_2 sent request with id: fs_client_2:29 to queue: requests_cola_1

# %%
# AsynResult.status updates the information every time it is called.
# 'PENDING' state should be assumed as transitory. 
# If there are responses available in the queue or in the cache 
# status or pending() updates the AsyncResult object.

[f.status for f in fs]
# Out:
# 2026-02-24T16:58:00.112672 Client: fs_client_2 received a Single RESULT with id: fs_client_2:19
# 2026-02-24T16:58:00.113872 Client: fs_client_2 received a Single RESULT with id: fs_client_2:20
# 2026-02-24T16:58:00.114466 Client: fs_client_2 received a Single RESULT with id: fs_client_2:21
# 2026-02-24T16:58:00.115221 Client: fs_client_2 received a Single RESULT with id: fs_client_2:22
# 2026-02-24T16:58:00.133360 Client: fs_client_2 received a Single RESULT with id: fs_client_2:23
# ['OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING']

# %%
client.wait_responses(timeout=2)
# Out:
# 2026-02-24T16:58:00.176888 Client: fs_client_2 received a Single RESULT with id: fs_client_2:24
# 2026-02-24T16:58:00.265871 Client: fs_client_2 received a Single RESULT with id: fs_client_2:25
# 2026-02-24T16:58:00.280780 Client: fs_client_2 received a Single RESULT with id: fs_client_2:26
# 2026-02-24T16:58:00.318479 Client: fs_client_2 received a Single RESULT with id: fs_client_2:27
# 2026-02-24T16:58:00.422349 Client: fs_client_2 received a Single RESULT with id: fs_client_2:28
# ['fs_client_2:29']

# %%
[f.status for f in fs]
# Out:
# ['OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'PENDING']

# %%
client.wait_responses()
# Out:
# 2026-02-24T16:58:10.485668 Client: fs_client_2 received a Single RESULT with id: fs_client_2:29
# []

# %%
# AsynResult.status updates information

[f.status for f in fs]
# Out:
# ['OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK', 'OK']

# %%
try:
    client.wait_responses(["kk", "qq"])
except ValueError as e:
    print(e)
# Out:
# wait_responses: ['kk', 'qq'] neither in responses nor in pending.

# %%
client._update_cache_with_all_available_responses()

# %%
client.pending
# Out:
# {}

# %%
[f.get() for f in fs]
# Out:
# [0.2953383523804363,
#  [0.5621065916950627, 0.899602866176034],
#  0.03660992227192918,
#  0.5201826640961561,
#  0.29833345138127665,
#  [0.7017459995498269, 0.1797879442681053],
#  0.0321666562613381,
#  0.5697520704400606,
#  0.94024330921464,
#  {'a': 0.6488811970352936, 'b': [0.6488811970352936, 0.719714747619113]},
#  None]

# %%
fs = client.rpc_batch_async(tp)
# Out:
# 2026-02-24T16:58:10.654021 Client: fs_client_2 sent batch request with 11 requests to queue: requests_cola_1

# %%
[f.get() for f in fs]
# Out:
# 2026-02-24T16:58:20.852462 Client: fs_client_2 received a Batch Response with 11 items
# 2026-02-24T16:58:20.853348 Client: fs_client_2 processed a RESULT with id: fs_client_2:30 from BATCH response
# 2026-02-24T16:58:20.853790 Client: fs_client_2 processed a RESULT with id: fs_client_2:31 from BATCH response
# 2026-02-24T16:58:20.854137 Client: fs_client_2 processed a RESULT with id: fs_client_2:32 from BATCH response
# 2026-02-24T16:58:20.854535 Client: fs_client_2 processed a RESULT with id: fs_client_2:33 from BATCH response
# 2026-02-24T16:58:20.854921 Client: fs_client_2 processed a RESULT with id: fs_client_2:34 from BATCH response
# 2026-02-24T16:58:20.855387 Client: fs_client_2 processed a RESULT with id: fs_client_2:35 from BATCH response
# 2026-02-24T16:58:20.856012 Client: fs_client_2 processed a RESULT with id: fs_client_2:36 from BATCH response
# 2026-02-24T16:58:20.856463 Client: fs_client_2 processed a RESULT with id: fs_client_2:37 from BATCH response
# 2026-02-24T16:58:20.856908 Client: fs_client_2 processed a RESULT with id: fs_client_2:38 from BATCH response
# 2026-02-24T16:58:20.857259 Client: fs_client_2 processed a RESULT with id: fs_client_2:39 from BATCH response
# 2026-02-24T16:58:20.857721 Client: fs_client_2 processed a RESULT with id: fs_client_2:40 from BATCH response
# [0.2953383523804363,
#  [0.5621065916950627, 0.899602866176034],
#  0.03660992227192918,
#  0.5201826640961561,
#  0.29833345138127665,
#  [0.7017459995498269, 0.1797879442681053],
#  0.0321666562613381,
#  0.5697520704400606,
#  0.94024330921464,
#  {'a': 0.6488811970352936, 'b': [0.6488811970352936, 0.719714747619113]},
#  None]

# %%
client.rpc_batch_sync(tp)
# Out:
# 2026-02-24T16:58:20.908110 Client: fs_client_2 sent batch request with 11 requests to queue: requests_cola_1
# 2026-02-24T16:58:31.027018 Client: fs_client_2 received a Batch Response with 11 items
# 2026-02-24T16:58:31.027730 Client: fs_client_2 processed a RESULT with id: fs_client_2:41 from BATCH response
# 2026-02-24T16:58:31.028240 Client: fs_client_2 processed a RESULT with id: fs_client_2:42 from BATCH response
# 2026-02-24T16:58:31.028673 Client: fs_client_2 processed a RESULT with id: fs_client_2:43 from BATCH response
# 2026-02-24T16:58:31.029237 Client: fs_client_2 processed a RESULT with id: fs_client_2:44 from BATCH response
# 2026-02-24T16:58:31.029853 Client: fs_client_2 processed a RESULT with id: fs_client_2:45 from BATCH response
# 2026-02-24T16:58:31.030379 Client: fs_client_2 processed a RESULT with id: fs_client_2:46 from BATCH response
# 2026-02-24T16:58:31.030788 Client: fs_client_2 processed a RESULT with id: fs_client_2:47 from BATCH response
# 2026-02-24T16:58:31.031285 Client: fs_client_2 processed a RESULT with id: fs_client_2:48 from BATCH response
# 2026-02-24T16:58:31.031856 Client: fs_client_2 processed a RESULT with id: fs_client_2:49 from BATCH response
# 2026-02-24T16:58:31.032698 Client: fs_client_2 processed a RESULT with id: fs_client_2:50 from BATCH response
# 2026-02-24T16:58:31.033210 Client: fs_client_2 processed a RESULT with id: fs_client_2:51 from BATCH response
# [0.2953383523804363,
#  [0.5621065916950627, 0.899602866176034],
#  0.03660992227192918,
#  0.5201826640961561,
#  0.29833345138127665,
#  [0.7017459995498269, 0.1797879442681053],
#  0.0321666562613381,
#  0.5697520704400606,
#  0.94024330921464,
#  {'a': 0.6488811970352936, 'b': [0.6488811970352936, 0.719714747619113]},
#  None]

# %%
fs =[]
tp = []
N = 10
for i in range(N):
    fn = random.choice(("add", "mul", "div", "fake"))
    t = (fn, [random.random(),random.random()], {})
    print(t)
    tp.append(t)
# Out:
# ('div', [0.5794513830424104, 0.5698141620293659], {})
# ('add', [0.21815417947786075, 0.9283973875398784], {})
# ('fake', [0.9886455605136555, 0.727962188241414], {})
# ('fake', [0.8814809516671883, 0.07302670720394511], {})
# ('div', [0.4070350099005292, 0.777704278769562], {})
# ('mul', [0.9518502881225048, 0.25431690120132344], {})
# ('mul', [0.42114671377479473, 0.9475713855988993], {})
# ('fake', [0.0496627109268728, 0.581098043712444], {})
# ('add', [0.5484164942834827, 0.9513654477898875], {})
# ('add', [0.37677289876817965, 0.3157633000379415], {})

# %%
tp
# Out:
# [('div', [0.5794513830424104, 0.5698141620293659], {}),
#  ('add', [0.21815417947786075, 0.9283973875398784], {}),
#  ('fake', [0.9886455605136555, 0.727962188241414], {}),
#  ('fake', [0.8814809516671883, 0.07302670720394511], {}),
#  ('div', [0.4070350099005292, 0.777704278769562], {}),
#  ('mul', [0.9518502881225048, 0.25431690120132344], {}),
#  ('mul', [0.42114671377479473, 0.9475713855988993], {}),
#  ('fake', [0.0496627109268728, 0.581098043712444], {}),
#  ('add', [0.5484164942834827, 0.9513654477898875], {}),
#  ('add', [0.37677289876817965, 0.3157633000379415], {})]

# %%
client.check_registry ="never"
client.set_default_queue("cola_1")

fs = client.rpc_batch_async(tp)
# Out:
# 2026-02-24T16:58:31.127459 Client: fs_client_2 sent batch request with 10 requests to queue: requests_cola_1

# %%
[f.safe_get() for f in fs]
# Out:
# 2026-02-24T16:58:31.267149 Client: fs_client_2 received a Batch Response with 10 items
# 2026-02-24T16:58:31.268074 Client: fs_client_2 processed a RESULT with id: fs_client_2:52 from BATCH response
# 2026-02-24T16:58:31.268625 Client: fs_client_2 processed a RESULT with id: fs_client_2:53 from BATCH response
# 2026-02-24T16:58:31.269189 Client: fs_client_2 processed a ERROR with id: fs_client_2:54 from BATCH response
# 2026-02-24T16:58:31.269682 Client: fs_client_2 processed a ERROR with id: fs_client_2:55 from BATCH response
# 2026-02-24T16:58:31.270268 Client: fs_client_2 processed a RESULT with id: fs_client_2:56 from BATCH response
# 2026-02-24T16:58:31.270829 Client: fs_client_2 processed a RESULT with id: fs_client_2:57 from BATCH response
# 2026-02-24T16:58:31.271716 Client: fs_client_2 processed a RESULT with id: fs_client_2:58 from BATCH response
# 2026-02-24T16:58:31.272652 Client: fs_client_2 processed a ERROR with id: fs_client_2:59 from BATCH response
# 2026-02-24T16:58:31.273544 Client: fs_client_2 processed a RESULT with id: fs_client_2:60 from BATCH response
# 2026-02-24T16:58:31.274295 Client: fs_client_2 processed a RESULT with id: fs_client_2:61 from BATCH response
# [1.0169129194309985,
#  1.146551567017739,
#  None,
#  None,
#  0.523380185775133,
#  0.2420716156829023,
#  0.3990665751120053,
#  None,
#  1.4997819420733702,
#  0.6925361988061212]

# %%
client.responses
# Out:
# {}

# %%
client.check_registry ="cache"

# %%
try:
    x = client.rpc_batch_sync(tp, timeout=5)
except Exception as e:
    print(e)
# Out:
# Method fake does not exist/is not available.

# %%
try:    
    x = client.rpc_batch_sync(tp, timeout=5)
except Exception as e:
    print(e)
# Out:
# Method fake does not exist/is not available.

# %%
client.check_registry="never"
client.set_default_queue("cola_1")

x = client.rpc_async("kk", [1, 0])
# Out:
# 2026-02-24T16:58:31.449432 Client: fs_client_2 sent request with id: fs_client_2:62 to queue: requests_cola_1

# %%
try:
    x.get()
except Exception as e:
    print(e)
# Out:
# 2026-02-24T16:58:31.599105 Client: fs_client_2 received a Single ERROR with id: fs_client_2:62
# Error -32601 : The method does not exist/is not available.

# %%
y = client.rpc_async("add", [1, 0])
# Out:
# 2026-02-24T16:58:31.631332 Client: fs_client_2 sent request with id: fs_client_2:63 to queue: requests_cola_1

# %%
y.get(5)
# Out:
# 2026-02-24T16:58:31.768706 Client: fs_client_2 received a Single RESULT with id: fs_client_2:63
# 1

# %%
def f(x,y): return x + y

client.check_registry = "never" # "never" use queue "default" don't work for rpc_async_fn or rpc_sync_fn 
y = client.rpc_async_fn(f, [1, 2.0])
try:
    print(y.get())
except Exception as e:
    print(e)
# Out:
# 2026-02-24T16:58:31.831782 Client: fs_client_2 sent request with id: fs_client_2:64 to queue: requests_cola_1
# 2026-02-24T16:58:31.999394 Client: fs_client_2 received a Single ERROR with id: fs_client_2:64
# Error -32601 : The method does not exist/is not available.

# %%
client.check_registry = "cache"
y = client.rpc_async_fn(f, [1, 2.0])
# Out:
# 2026-02-24T16:58:32.049026 Client: fs_client_2 sent request with id: fs_client_2:65 to queue: requests_py_eval

# %%
y.get()
# Out:
# 2026-02-24T16:58:32.211622 Client: fs_client_2 received a Single RESULT with id: fs_client_2:65
# 3.0

# %%
[k for k in client.responses.keys()]
# Out:
# []

# %%
client.clean_used()

# %%
[k for k in client.responses.keys()]
# Out:
# []

# %%
resultados
# Out:
# [0.2953383523804363,
#  [0.5621065916950627, 0.899602866176034],
#  0.03660992227192918,
#  0.5201826640961561,
#  0.29833345138127665,
#  [0.7017459995498269, 0.1797879442681053],
#  0.0321666562613381,
#  0.5697520704400606,
#  0.94024330921464,
#  {'a': 0.6488811970352936, 'b': [0.6488811970352936, 0.719714747619113]},
#  None]

# %%
client.rpc_sync_fn(print, ["hola"])
# Out:
# 2026-02-24T16:58:32.357990 Client: fs_client_2 sent request with id: fs_client_2:66 to queue: requests_py_eval
# 2026-02-24T16:58:32.507165 Client: fs_client_2 received a Single RESULT with id: fs_client_2:66

# %%
fs =[]
tp = []
N = 10
for i in range(N):
    fn = random.choice(("sleep", "sleep"))
    t = (fn, [15], {})
    print(t)
    tp.append(t)
# Out:
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})
# ('sleep', [15], {})

# %%
client.check_registry="never"
fs = client.rpc_multi_async(tp, retry=True)
# Out:
# 2026-02-24T16:58:32.577599 Client: fs_client_2 sent request with id: fs_client_2:67 to queue: requests_cola_1
# 2026-02-24T16:58:32.596993 Client: fs_client_2 sent request with id: fs_client_2:68 to queue: requests_cola_1
# 2026-02-24T16:58:32.614248 Client: fs_client_2 sent request with id: fs_client_2:69 to queue: requests_cola_1
# 2026-02-24T16:58:32.632965 Client: fs_client_2 sent request with id: fs_client_2:70 to queue: requests_cola_1
# 2026-02-24T16:58:32.657411 Client: fs_client_2 sent request with id: fs_client_2:71 to queue: requests_cola_1
# 2026-02-24T16:58:32.676604 Client: fs_client_2 sent request with id: fs_client_2:72 to queue: requests_cola_1
# 2026-02-24T16:58:32.707868 Client: fs_client_2 sent request with id: fs_client_2:73 to queue: requests_cola_1
# 2026-02-24T16:58:32.731697 Client: fs_client_2 sent request with id: fs_client_2:74 to queue: requests_cola_1
# 2026-02-24T16:58:32.765660 Client: fs_client_2 sent request with id: fs_client_2:75 to queue: requests_cola_1
# 2026-02-24T16:58:32.795320 Client: fs_client_2 sent request with id: fs_client_2:76 to queue: requests_cola_1

# %%
from time import time

def gather(arl, timeout=None, step=5, max_dts=0):
    # Update to reset delta times
    pending_ars = [ar for ar in arl if not(ar.ok() or ar.failed())] 
    pending_ids = [ar.id for ar in pending_ars]
    if fs[0]._client.wait_responses(pending_ids, timeout=0) == []:
        return

    N = len(arl)

    max_dts = max_dts

    t_0 = time()

    i = 0
    # ok() and failed() don't update.
    # pending() updates, every time is called, all the ids 
    # that have a response available in the queue 
    pending_ars = [ar for ar in arl if not(ar.ok() or ar.failed())]
    pending_ars0= pending_ars
    pending_ids = [ar.id for ar in pending_ars]
    t_prev = time()
    n_pending_prev = len(pending_ars)
    n_pending_0 = n_pending_prev    
    while (time() - t_0) <= timeout:
        try:
            if fs[0]._client.wait_responses(pending_ids, timeout=5) == []:
                return
        except TimeoutError:
            pass
        dts = [ar.finished_time - t_0 for ar in pending_ars0 if (ar.ok() or ar.failed())]
        if len(dts)>0:
            #max_dts = max(max_dts, max(dts))
            max_dts = max(dts)    
        pending_ars = [ar for ar in arl if not(ar.ok() or ar.failed())] 
        pending_ids = [ar.id for ar in pending_ars]
        if len(pending_ars) < n_pending_prev:
            t_prev = time()
            n_pending_prev = len(pending_ars)  

        avg =  (time()-t_0)/(n_pending_0 -len(pending_ars)) if (n_pending_0 -len(pending_ars))>0 else 0

        print(f"{i}: seconds {time()-t_0}s, AR recovered {N-len(pending_ars)}, \
                AR left {len(pending_ars)}, max delta {max_dts}, avg {avg}")
        i += 0

# %%
gather(fs, 30, 5)
# Out:
# 0: seconds 5.171956300735474s, AR recovered 0,                 AR left 10, max delta 0, avg 0
# 0: seconds 10.27873945236206s, AR recovered 0,                 AR left 10, max delta 0, avg 0
# 2026-02-24T16:58:47.708574 Client: fs_client_2 received a Single RESULT with id: fs_client_2:67
# 0: seconds 15.428331851959229s, AR recovered 1,                 AR left 9, max delta 14.834151029586792, avg 15.428329467773438
# 0: seconds 20.526084184646606s, AR recovered 1,                 AR left 9, max delta 14.834151029586792, avg 20.526081800460815
# 0: seconds 25.67121148109436s, AR recovered 1,                 AR left 9, max delta 14.834151029586792, avg 25.671209812164307
# 2026-02-24T16:59:02.812888 Client: fs_client_2 received a Single RESULT with id: fs_client_2:68
# 0: seconds 30.795242071151733s, AR recovered 2,                 AR left 8, max delta 29.93846559524536, avg 15.39762032032013

# %%
[f.status for f in fs]
# Out:
# ['OK',
#  'OK',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING',
#  'PENDING']

# %%
[(time() if f.finished_time is None else f.finished_time) -f.creation_time for f in fs]
# Out:
# [15.129861831665039,
#  30.214876651763916,
#  31.09479331970215,
#  31.076401472091675,
#  31.051655292510986,
#  31.032496213912964,
#  31.000258445739746,
#  30.977018356323242,
#  30.942534923553467,
#  30.91183614730835]

# %%
[f.finished_time for f in fs]
# Out:
# [1771948727.7085705,
#  1771948742.812885,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
client.pending
# Out:
# {'fs_client_2:69': 1771948712.6152594,
#  'fs_client_2:70': 1771948712.6336524,
#  'fs_client_2:71': 1771948712.6583982,
#  'fs_client_2:72': 1771948712.6775577,
#  'fs_client_2:73': 1771948712.7097938,
#  'fs_client_2:74': 1771948712.7330341,
#  'fs_client_2:75': 1771948712.7675188,
#  'fs_client_2:76': 1771948712.7982156}

# %%
fs[3].status
# Out:
# 'PENDING'

# %%
fs[0].retry()
# Out:
# 2026-02-24T16:59:03.809404 Client: fs_client_2 Not Retrying: Response to Request with id: fs_client_2:67 already received.

# %%
[f.retry() for f in fs if ok is not None]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 [f.retry() for f in fs if ok is not None]
#
# NameError: name 'ok' is not defined

# %%
import datetime

# %%
datetime.datetime.now().isoformat()
# Out:
# '2025-10-29T18:22:36.906351'

# %%
from datetime import datetime

# %%
client.check_registry="always"
client.all_queues_for_method("info")
# Out:
# ['requests_fs_server_1', 'requests_fs_server_2']

# %%
client.connector.all_queues_for_method("info")
# Out:
# ['requests_fs_server_1', 'requests_fs_server_2']

# %%
client.update_registry()
# Out:
# registry_lock set
# registry_lock unset

# %%
client.check_registry="Never"
client.all_queues_for_method("hola")
# Out:
# ['requests_cola_1']

# %%
client.check_registry="always"
a = client.rpc_async("info")
# Out:
# 2025-10-29T18:22:37.090210 Client: fs_client_2 sent request with id: fs_client_2:77 to queue: requests_fs_server_2

# %%
client.rpc_sync("div", [2,1], timeout=10)
# Out:
# 2025-10-29T18:22:37.118667 Client: fs_client_2 sent request with id: fs_client_2:78 to queue: requests_cola_1
# 2025-10-29T18:22:37.260453 Client: fs_client_2 received a Single RESULT with id: fs_client_2:77
# 2025-10-29T18:22:37.273416 Client: fs_client_2 received a Single RESULT with id: fs_client_2:78
# 2.0

# %%
x = a.get()

# %%
x[1]["requests_cola_1"]["add"](1,2)
# Out:
# 3

# %%
client.registry
# Out:
# {'add': ['requests_cola_1'],
#  'dic': ['requests_cola_1'],
#  'div': ['requests_cola_1'],
#  'eval_py_function': ['requests_py_eval'],
#  'info': ['requests_fs_server_1', 'requests_fs_server_2'],
#  'lista': ['requests_cola_1'],
#  'mul': ['requests_cola_1'],
#  'sleep': ['requests_cola_1'],
#  'tupla': ['requests_cola_1']}

# %%
def registry_one_step(x):
    worker_id = x[0]
    registry = {}
    for queue, methods in x[1].items():
        for method in methods:
            if method in registry:
                registry[method].append(queue)
            else:
                registry[method] = [queue]
    return registry 

def queues_workers_one_step(x):
    worker_id = x[0]
    registry = {}
    for queue in x[1]:
        if queue in registry:
            registry[queue].append(worker_id)
        else:
            registry[queue] = [worker_id]
    return registry 

def all_workers_for_queue():
    # all requests queues for "info" method
    # One queue per worker

    rr = {}
    qq = {}
    all_worker_queues = client.connector.all_queues_for_method("info")
    for worker in all_worker_queues:
        try:
            x = client.rpc_sync("info", timeout=10)
        except TimeoutError:
            x = None
        
        if x is not None:
            for method, qs in registry_one_step(x).items():
                if method not in rr:
                    rr[method] = qs
                else:
                    rr[method] += qs
            for q, ws in queues_workers_one_step(x).items():
                if q not in qq:
                    qq[q] = ws
                else:
                    qq[q] += ws
    return rr, qq

# %%
registry_one_step(x)
# Out:
# {'info': ['requests_fs_server_2'],
#  'add': ['requests_cola_1'],
#  'mul': ['requests_cola_1'],
#  'div': ['requests_cola_1'],
#  'lista': ['requests_cola_1'],
#  'tupla': ['requests_cola_1'],
#  'dic': ['requests_cola_1'],
#  'sleep': ['requests_cola_1'],
#  'hola': ['requests_cola_2'],
#  'eval_py_function': ['requests_py_eval']}

# %%
queues_workers_one_step(x)
# Out:
# {'requests_fs_server_2': ['fs_server_2'],
#  'requests_cola_1': ['fs_server_2'],
#  'requests_cola_2': ['fs_server_2'],
#  'requests_py_eval': ['fs_server_2']}

# %%
r, q = all_workers_for_queue()
# Out:
# 2025-10-29T18:22:37.461400 Client: fs_client_2 sent request with id: fs_client_2:79 to queue: requests_fs_server_1
# 2025-10-29T18:22:37.661109 Client: fs_client_2 received a Single RESULT with id: fs_client_2:79
# 2025-10-29T18:22:37.681071 Client: fs_client_2 sent request with id: fs_client_2:80 to queue: requests_fs_server_2
# 2025-10-29T18:22:37.924273 Client: fs_client_2 received a Single RESULT with id: fs_client_2:80

# %%
r
# Out:
# {'info': ['requests_fs_server_1', 'requests_fs_server_2'],
#  'add': ['requests_cola_1', 'requests_cola_1'],
#  'mul': ['requests_cola_1', 'requests_cola_1'],
#  'div': ['requests_cola_1', 'requests_cola_1'],
#  'lista': ['requests_cola_1', 'requests_cola_1'],
#  'tupla': ['requests_cola_1', 'requests_cola_1'],
#  'dic': ['requests_cola_1', 'requests_cola_1'],
#  'sleep': ['requests_cola_1', 'requests_cola_1'],
#  'hola': ['requests_cola_2', 'requests_cola_2'],
#  'eval_py_function': ['requests_py_eval', 'requests_py_eval']}

# %%
q
# Out:
# {'requests_fs_server_1': ['fs_server_1'],
#  'requests_cola_1': ['fs_server_1', 'fs_server_2'],
#  'requests_cola_2': ['fs_server_1', 'fs_server_2'],
#  'requests_py_eval': ['fs_server_1', 'fs_server_2'],
#  'requests_fs_server_2': ['fs_server_2']}

# %%
t = (1,2,3,4)

# %%
t[:6]
# Out:
# (1, 2, 3, 4)

# %%
t[:5]
# Out:
# (1, 2, 3, 4)
