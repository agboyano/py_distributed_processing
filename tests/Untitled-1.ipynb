# %%
import fs_structs

# %%
NS_PATH = "c:\\fs_namespaces\\prueba_distribuida"

# %%
ns = fs_structs.structs.FSNamespace(NS_PATH)

# %%
ns.variables['method_queues_add']
# Out:
# {'requests_cola_1'}

# %%
ns.variables['method_queues_add']
# Out:
# {'requests_cola_1'}

# %%
[x.removeprefix('method_queues_') for x in ns.variables.keys() if x.startswith("method_queues_")]
# Out:
# ['add', 'div', 'eval_py_function', 'mul']

# %%
'method_queues_add'.removeprefix('method_queues_')
# Out:
# 'add'

# %%
ns.names()
# Out:
# ['requests_cola_1',
#  'requests_cola_2',
#  'requests_fs_server_1',
#  'requests_py_eval',
#  'registry',
#  'variables']
