# %%
from time import sleep

from distributed_processing.utils import fsworker

# %%
CURRO = True

if CURRO:
    NS_PATH ="G:\\fs_namespaces\\prueba_distribuida"
    NS_PATH ="C:\\fs_namespaces\\prueba_distribuida"

else:
    NS_PATH = "/home/augusto/python/notebooks/fs_namespaces/prueba_distribuida"

# %%
import logging

logging.getLogger("distributed_processing").setLevel(logging.DEBUG)

# %%
# clean = True limpia namespace. Por defecto, False 
server = fsworker(NS_PATH, clean=True)
# Out:
# Worker id: fs_server_1

# %%
def info():
    return server.worker_id, server.requests_queues

server.add_requests_queue(server.worker_id, {"info":info})

# %%
def add(x, y):
    return x + y

def mul(x, y):
    return x * y

def div(x, y):
    return x / y

def lista(x, y):
    return [x, y]

def tupla(x, y):
    return (x,y)

def dic(x,y):
    return {"a":x, "b":[x,y]}

func_dict1 = {"add" : add,
              "mul" : mul,
              "div" : div,
              "lista" : lista,
              "tupla" : tupla,
              "dic" :dic,
              "sleep": sleep}

server.add_requests_queue("cola_1", func_dict1)

# %%
def hola(nombre, calificativo="listo"):
    return f"Hola {nombre}, eres muy {calificativo}"

func_dict2 = {"hola": hola}

# Los métodos disponibles en cola_2 no los vamos a hacer públicos
server.add_requests_queue("cola_2", func_dict2, register=False)

# %%
server.add_python_eval()

"""
# Equivalente a:
import dill
import base64

def eval_py_function(str_fn, args=[], kwargs={}):
    "str_fn encoded en base64 ascii"
    return dill.loads(base64.b64decode(str_fn))(*args, **kwargs)

server.add_requests_queue("py_eval", {"eval_py_function": eval_py_function})
"""
# Out:
# '\n# Equivalente a:\nimport dill\nimport base64\n\ndef eval_py_function(str_fn, args=[], kwargs={}):\n    "str_fn encoded en base64 ascii"\n    return dill.loads(base64.b64decode(str_fn))(*args, **kwargs)\n\nserver.add_requests_queue("py_eval", {"eval_py_function": eval_py_function})\n'

# %%
server.queues_to_register
# Out:
# {'requests_cola_1', 'requests_fs_server_1', 'requests_py_eval'}

# %%
# Publicamos todos los métodos de las colas 
server.update_methods_registry()
# Out:
# Method info published as available for queues: requests_fs_server_1
# Method add published as available for queues: requests_cola_1
# Method mul published as available for queues: requests_cola_1
# Method div published as available for queues: requests_cola_1
# Method lista published as available for queues: requests_cola_1
# Method tupla published as available for queues: requests_cola_1
# Method dic published as available for queues: requests_cola_1
# Method sleep published as available for queues: requests_cola_1
# Method eval_py_function published as available for queues: requests_py_eval

# %%
server.run()
# Out:
# 2026-03-16T13:07:43.825729 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:43.853370 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:1 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:44.028454 Worker: fs_server_1 Received Single Request for method: fake from queue: requests_cola_1
# 2026-03-16T13:07:44.048411 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:2 for method: fake to queue: fs_client_1_responses
# 2026-03-16T13:07:44.206434 Worker: fs_server_1 Received Single Request for method: fake from queue: requests_cola_1
# 2026-03-16T13:07:44.233119 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:3 for method: fake to queue: fs_client_1_responses
# 2026-03-16T13:07:44.463421 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-03-16T13:07:44.508627 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:4 for method: div to queue: fs_client_1_responses
# 2026-03-16T13:07:44.747540 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:44.775099 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:5 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:44.977475 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_py_eval
# 2026-03-16T13:07:44.996899 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:6 for method: eval_py_function to queue: fs_client_1_responses
# 2026-03-16T13:07:45.123323 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_py_eval
# 2026-03-16T13:07:45.147837 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:7 for method: eval_py_function to queue: fs_client_1_responses
# 2026-03-16T13:07:45.358698 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-03-16T13:07:45.380389 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:8 for method: lista to queue: fs_client_1_responses
# 2026-03-16T13:07:45.413316 Worker: fs_server_1 Received Single Request for method: tupla from queue: requests_cola_1
# 2026-03-16T13:07:45.435851 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:9 for method: tupla to queue: fs_client_1_responses
# 2026-03-16T13:07:45.465995 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:45.486321 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:10 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:45.510401 Worker: fs_server_1 Received Single Request for method: dic from queue: requests_cola_1
# 2026-03-16T13:07:45.534923 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:11 for method: dic to queue: fs_client_1_responses
# 2026-03-16T13:07:45.562185 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:45.593341 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:12 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:45.646135 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:45.676584 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:13 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:45.711503 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-03-16T13:07:45.734523 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:14 for method: lista to queue: fs_client_1_responses
# 2026-03-16T13:07:45.771560 Worker: fs_server_1 Received Single Request for method: mul from queue: requests_cola_1
# 2026-03-16T13:07:45.795825 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:15 for method: mul to queue: fs_client_1_responses
# 2026-03-16T13:07:45.825609 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-03-16T13:07:45.846630 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:16 for method: lista to queue: fs_client_1_responses
# 2026-03-16T13:07:45.879631 Worker: fs_server_1 Received Single Request for method: tupla from queue: requests_cola_1
# 2026-03-16T13:07:45.901660 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:17 for method: tupla to queue: fs_client_1_responses
# 2026-03-16T13:07:45.924521 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:07:55.944326 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:18 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:07:56.090900 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-03-16T13:07:56.110240 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:19 for method: lista to queue: fs_client_1_responses
# 2026-03-16T13:07:56.139940 Worker: fs_server_1 Received Single Request for method: tupla from queue: requests_cola_1
# 2026-03-16T13:07:56.160710 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:20 for method: tupla to queue: fs_client_1_responses
# 2026-03-16T13:07:56.188420 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:56.209477 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:21 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:56.238073 Worker: fs_server_1 Received Single Request for method: dic from queue: requests_cola_1
# 2026-03-16T13:07:56.256794 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:22 for method: dic to queue: fs_client_1_responses
# 2026-03-16T13:07:56.284980 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:56.309713 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:23 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:56.335022 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:07:56.363886 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:24 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:07:56.419795 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-03-16T13:07:56.448304 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:25 for method: lista to queue: fs_client_1_responses
# 2026-03-16T13:07:56.479458 Worker: fs_server_1 Received Single Request for method: mul from queue: requests_cola_1
# 2026-03-16T13:07:56.505822 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:26 for method: mul to queue: fs_client_1_responses
# 2026-03-16T13:07:56.528670 Worker: fs_server_1 Received Single Request for method: lista from queue: requests_cola_1
# 2026-03-16T13:07:56.551264 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:27 for method: lista to queue: fs_client_1_responses
# 2026-03-16T13:07:56.570246 Worker: fs_server_1 Received Single Request for method: tupla from queue: requests_cola_1
# 2026-03-16T13:07:56.590557 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:28 for method: tupla to queue: fs_client_1_responses
# 2026-03-16T13:07:56.611918 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:08:06.634291 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:29 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:08:06.937175 Worker: fs_server_1 Received Batch Request with 11 requests from queue: requests_cola_1
# 2026-03-16T13:08:16.938566 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:30 for method: lista from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.939357 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:31 for method: tupla from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.939757 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:32 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.940652 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:33 for method: dic from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.941147 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:34 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.941671 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:35 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.942177 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:36 for method: lista from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.942606 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:37 for method: mul from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.943050 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:38 for method: lista from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.943423 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:39 for method: tupla from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.943895 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:40 for method: sleep from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:16.962557 Worker: fs_server_1 Sent Batch Response with 11 items to queue fs_client_1_responses
# 2026-03-16T13:08:17.059209 Worker: fs_server_1 Received Batch Request with 11 requests from queue: requests_cola_1
# 2026-03-16T13:08:27.060827 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:41 for method: lista from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.061570 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:42 for method: tupla from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.062037 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:43 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.062479 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:44 for method: dic from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.062950 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:45 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.063506 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:46 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.063931 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:47 for method: lista from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.064378 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:48 for method: mul from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.064861 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:49 for method: lista from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.065273 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:50 for method: tupla from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.065727 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:51 for method: sleep from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.092084 Worker: fs_server_1 Sent Batch Response with 11 items to queue fs_client_1_responses
# 2026-03-16T13:08:27.331028 Worker: fs_server_1 Received Batch Request with 10 requests from queue: requests_cola_1
# 2026-03-16T13:08:27.331706 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:52 for method: mul from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.332230 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:53 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.332692 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:54 for method: mul from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.333132 Worker: fs_server_1 Appending ERROR response with id: fs_client_1:55 for method: fake from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.333462 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:56 for method: div from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.333895 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:57 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.334356 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:58 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.334966 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:59 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.335992 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:60 for method: mul from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.336613 Worker: fs_server_1 Appending RESULT response with id: fs_client_1:61 for method: add from Batch Request from queue: requests_cola_1
# 2026-03-16T13:08:27.356433 Worker: fs_server_1 Sent Batch Response with 10 items to queue fs_client_1_responses
# 2026-03-16T13:08:27.681736 Worker: fs_server_1 Received Single Request for method: kk from queue: requests_cola_1
# 2026-03-16T13:08:27.705749 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:62 for method: kk to queue: fs_client_1_responses
# 2026-03-16T13:08:27.915817 Worker: fs_server_1 Received Single Request for method: add from queue: requests_cola_1
# 2026-03-16T13:08:27.947204 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:63 for method: add to queue: fs_client_1_responses
# 2026-03-16T13:08:28.125558 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_cola_1
# 2026-03-16T13:08:28.148222 Worker: fs_server_1 Sent Single ERROR Response with id fs_client_1:64 for method: eval_py_function to queue: fs_client_1_responses
# 2026-03-16T13:08:28.292817 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_py_eval
# 2026-03-16T13:08:28.312343 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:65 for method: eval_py_function to queue: fs_client_1_responses
# 2026-03-16T13:08:28.641757 Worker: fs_server_1 Received Single Request for method: eval_py_function from queue: requests_py_eval
# 2026-03-16T13:08:28.664457 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:66 for method: eval_py_function to queue: fs_client_1_responses
# 2026-03-16T13:08:28.818778 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# hola
# 2026-03-16T13:08:43.840174 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:67 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:08:43.862463 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:08:58.883791 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:68 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:08:58.904197 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:09:13.923240 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:69 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:09:13.942884 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:09:28.962315 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:70 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:09:28.981560 Worker: fs_server_1 Received Single Request for method: info from queue: requests_fs_server_1
# 2026-03-16T13:09:28.999291 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:77 for method: info to queue: fs_client_1_responses
# 2026-03-16T13:09:29.018813 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:09:44.039097 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:71 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:09:44.058593 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:09:59.092095 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:72 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:09:59.122111 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:10:14.141574 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:73 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:10:14.161250 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:10:29.187279 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:74 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:10:29.222522 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:10:44.241770 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:75 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:10:44.264585 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:10:59.285357 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:76 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:10:59.306828 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:11:14.327148 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:71 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:11:14.346887 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:11:29.380666 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:69 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:11:29.427570 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:11:44.449877 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:70 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:11:44.472920 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:11:59.497959 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:71 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:11:59.519507 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:12:14.538879 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:72 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:12:14.563117 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:12:29.586532 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:73 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:12:29.609504 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:12:44.630768 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:74 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:12:44.651624 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:12:59.674360 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:75 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:12:59.692932 Worker: fs_server_1 Received Single Request for method: sleep from queue: requests_cola_1
# 2026-03-16T13:13:14.715838 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:76 for method: sleep to queue: fs_client_1_responses
# 2026-03-16T13:13:14.735443 Worker: fs_server_1 Received Single Request for method: div from queue: requests_cola_1
# 2026-03-16T13:13:14.753616 Worker: fs_server_1 Sent Single RESULT Response with id fs_client_1:78 for method: div to queue: fs_client_1_responses
